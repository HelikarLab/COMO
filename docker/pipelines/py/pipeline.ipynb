# %% [markdown]
# ## Instructions
#
# This jupyter notebook run MADRID pipeline to identify drug targets and repurposing drugs for user-defined complex human diseases. The entire process contains four steps:
# 1. Download and analyze transcriptomics and proteomics data, output a list of active genes.
# 2. Create tissue specific models based on the list of active genes. If required the user can manually refine these models and supply them in Step 4.
# 3. Identifying differential gene expressions from disease datasets.
# 4. Identifying drug targets and repruposable drugs. This step consists of four substeps.
#  (i) mapping drugs on automatically created or user-supplied models, (ii) knock-out simulation, (iii) compare simulation results of perturbed and unperturbed models, and (iv) integrate with disease genes and score drug targets.
#
# The users needs to create the input files for each step and upload input files to the docker container `/root/pipelines/data/`, and specify the input files in this notebook. In the original docker image, some exemplary input files are included to build metabolic models of naive, Th1, Th2, and Th17 subtypes and identify drug targets for rheumatoid arthritis. User should follow the documentation and the format of the exemplary input files to create your own input files.

# %%
# import necessary python packages
import sys
import os
import pandas
import numpy
import json
import re
from subprocess import call
from project import configs

# print root path of the project
print(configs.rootdir)
# Out:
# G:/GitHub/MADRID/docker/pipelines/

# %% [markdown]
# ## Step 1: Identifying gene activity by analyzing transcriptomics and proteomics datasets

# %% [markdown]
# *** Specify input files for step 1 here ***
#
# If proteomics data is not availabe, use:
#
# proteomics_data_file = 'dummy_proteomics_data.xlsx'
#
# proteomics_config_file = 'dummy_proteomics_config.xlsx'

# %%
# Step 0: Generate count matrix from gene counts files generated from STAR

technique = "quantile" # technique for bulk RNA-seq active gene determination
                        # for count matrix gen, only used to determine whether or not
                        # picard output mean fragment sizes are required.
        
input_dir = "G:/GitHub/New Folder/MADRID_olddev/docker/pipelines/py/data/bulkData/NaiveB/"
output_dir = "G:/GitHub/MADRID/docker/pipelines/data/"
        
cmd = ' '.join(['python', 'generateCountMatrix.py',
                '-i', '"{}"'.format(input_dir),
                '-o', '"{}"'.format(output_dir),
                '-t', '"{}"'.format(technique)])
#print(cmd)
# !{cmd}
# Alternatively, the gene count matrix for RNA-seq can be crafted any other way desired
# and this step can be skipped
# Out:
# ['generateCountMatrix.py', '-i', 'G:/GitHub/New Folder/MADRID_olddev/docker/pipelines/py/data/bulkData/NaiveB/', '-o', 'G:/GitHub/MADRID/docker/pipelines/data/', '-t', 'quantile']
# Input directory is "G:/GitHub/New Folder/MADRID_olddev/docker/pipelines/py/data/bulkData/NaiveB/"
# Output file is "G:/GitHub/MADRID/docker/pipelines/data/"
# Active gene determination technique is "quantile"
# C:\Users\babes\Anaconda3\lib\site-packages\rpy2\robjects\pandas2ri.py:17: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import Index as PandasIndex

# %%
# wd for development

# Specific input files for step 1

# config file for transcriptomics (microarray)
transcriptomics_config_file = 'transcriptomics_data_inputs.xlsx'

# data file for bulk rna-seq
bulk_data_file = 'BulkRNAseqDataMatrix.csv'

# config for bulk rna-seq
bulk_config_file = 'bulk_data_inputs.csv'

# data file for proteomics
proteomics_data_file = 'ProteomicsDataMatrix.xlsx' 

# config file for proteomics
proteomics_config_file = 'proteomics_data_inputs.xlsx'

# proportion of replicates required for a gene to be considered active in that sample

expression_proportion = 0.5
# if gene is in the top nth percentile in any sample it is considered high confidence and will be considered
# expressed regardless of the results of other methods
top_percentile =  10

# %%
# Step 1.1 Download and analyze transcriptomics
cmd = ' '.join(['python', 'transcriptomic_gen.py', 
      '-i', '"{}"'.format(transcriptomics_config_file)])
# !{cmd}
# Out:
# Input file is " transcriptomics_data_inputs.xlsx
# G:/GitHub/MADRID/docker/pipelines/data\transcriptomics_data_inputs.xlsx
# ---
# Start Collecting Data for:
# ['GSE22886' 'GSE43005' 'GSE22045' 'GSE24634']
# ['GSM565273' 'GSM565274' 'GSM565275' 'GSM565290' 'GSM565291' 'GSM565292'
#  'GSM1054773' 'GSM1054779' 'GSM1054781' 'GSM1054789' 'GSM548000'
#  'GSM548001' 'GSM607510' 'GSM607511' 'GSM607512']
# ---
#
# Initialize project (GSE22886):
# Root: G:/GitHub/MADRID/docker/pipelines/
# Raw data: G:/GitHub/MADRID/docker/pipelines/data\GSE22886_RAW
# Retrieve Sample: G:/GitHub/MADRID/docker/pipelines/data\GSE22886_RAW\GSM565273.tar
# Extract to: G:/GitHub/MADRID/docker/pipelines/data\GSE22886_RAW\GPL96
# Retrieve Sample: G:/GitHub/MADRID/docker/pipelines/data\GSE22886_RAW\GSM565274.tar
# Extract to: G:/GitHub/MADRID/docker/pipelines/data\GSE22886_RAW\GPL96
# Retrieve Sample: G:/GitHub/MADRID/docker/pipelines/data\GSE22886_RAW\GSM565275.tar
# Extract to: G:/GitHub/MADRID/docker/pipelines/data\GSE22886_RAW\GPL96
# Retrieve Sample: G:/GitHub/MADRID/docker/pipelines/data\GSE22886_RAW\GSM565290.tar
# Extract to: G:/GitHub/MADRID/docker/pipelines/data\GSE22886_RAW\GPL96
# Retrieve Sample: G:/GitHub/MADRID/docker/pipelines/data\GSE22886_RAW\GSM565291.tar
# Extract to: G:/GitHub/MADRID/docker/pipelines/data\GSE22886_RAW\GPL96
# Retrieve Sample: G:/GitHub/MADRID/docker/pipelines/data\GSE22886_RAW\GSM565292.tar
# Extract to: G:/GitHub/MADRID/docker/pipelines/data\GSE22886_RAW\GPL96
# Retrieve Samples Completed.
# Create new table: G:/GitHub/MADRID/docker/pipelines/data\GSE22886_RAW\GSE22886_sc500_full_table.csv
# D: 0% -  4.0KiB  / 41.1MiB  eta unknown
# D: 0% -  8.0KiB  / 41.1MiB  eta unknown
# D: 0% - 12.0KiB  / 41.1MiB  eta unknown
# D: 0% - 16.0KiB  / 41.1MiB  eta unknown
# D: 0% - 20.0KiB  / 41.1MiB  eta unknown
# D: 0% - 24.0KiB  / 41.1MiB  eta unknown
# D: 0% - 28.0KiB  / 41.1MiB  eta unknown
# D: 0% - 32.0KiB  / 41.1MiB  eta unknown
# D: 0% - 36.0KiB  / 41.1MiB  eta unknown
# D: 0% - 40.0KiB  / 41.1MiB  eta unknown
# D: 0% - 44.0KiB  / 41.1MiB  eta unknown
# D: 0% - 48.0KiB  / 41.1MiB  eta unknown
# D: 0% - 52.0KiB  / 41.1MiB  eta unknown
# D: 0% - 56.0KiB  / 41.1MiB  eta unknown
# D: 0% - 60.0KiB  / 41.1MiB  eta unknown
# D: 0% - 64.0KiB  / 41.1MiB  eta unknown
# C:\Users\babes\Anaconda3\lib\site-packages\rpy2\robjects\pandas2ri.py:17: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import Index as PandasIndex
# 10-May-2021 13:51:38 INFO GEOparse - Downloading ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE22nnn/GSE22886/soft/GSE22886_family.soft.gz to ./GSE22886_family.soft.gz
# 10-May-2021 13:51:38 INFO utils - Downloading ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE22nnn/GSE22886/soft/GSE22886_family.soft.gz to ./GSE22886_family.soft.gz
#
# 10-May-2021 13:51:45 INFO GEOparse - Parsing ./GSE22886_family.soft.gz:
# 10-May-2021 13:51:45 DEBUG GEOparse - DATABASE: GeoMiame
# 10-May-2021 13:51:45 DEBUG GEOparse - SERIES: GSE22886
# 10-May-2021 13:51:45 DEBUG GEOparse - PLATFORM: GPL96
# Traceback (most recent call last):
#   File "transcriptomic_gen.py", line 347, in <module>
#     main(sys.argv[1:])
#   File "transcriptomic_gen.py", line 338, in main
#     df_output = queryTest(df)
#   File "transcriptomic_gen.py", line 140, in queryTest
#     updateTranscriptomicsDB(gseXXX)
#   File "transcriptomic_gen.py", line 84, in updateTranscriptomicsDB
#     df_clean = gseXXX.get_entrez_table_pipeline()
#   File "G:\GitHub\MADRID\docker\pipelines\py\GSEpipelineFast.py", line 182, in get_entrez_table_pipeline
#     gsm_maps = self.get_gsm_tables()
#   File "G:\GitHub\MADRID\docker\pipelines\py\GSEpipelineFast.py", line 125, in get_gsm_tables
#     gse = load_gse_soft(self.gsename)
#   File "G:\GitHub\MADRID\docker\pipelines\py\GSEpipeline.py", line 25, in load_gse_soft
#     gse = GEOparse.get_GEO(geo=name, destdir="./")
#   File "C:\Users\babes\Anaconda3\lib\site-packages\GEOparse\GEOparse.py", line 84, in get_GEO
#     return parse_GSE(filepath)
#   File "C:\Users\babes\Anaconda3\lib\site-packages\GEOparse\GEOparse.py", line 521, in parse_GSE
#     gpls[entry_name] = parse_GPL(data_group, entry_name)
#   File "C:\Users\babes\Anaconda3\lib\site-packages\GEOparse\GEOparse.py", line 462, in parse_GPL
#     table_data = parse_table_data(gpl_soft)
#   File "C:\Users\babes\Anaconda3\lib\site-packages\GEOparse\GEOparse.py", line 332, in parse_table_data
#     return DataFrame.from_csv(StringIO(data), index_col=None, sep="\t")
# AttributeError: type object 'DataFrame' has no attribute 'from_csv'
# D: 0% - 68.0KiB  / 41.1MiB  eta unknown
# D: 0% - 72.0KiB  / 41.1MiB  eta unknown
# D: 0% - 76.0KiB  / 41.1MiB  eta unknown
# D: 0% - 80.0KiB  / 41.1MiB  eta unknown
# D: 0% - 84.0KiB  / 41.1MiB  eta unknown
# D: 0% - 88.0KiB  / 41.1MiB  eta unknown
# D: 0% - 92.0KiB  / 41.1MiB  eta unknown
# D: 0% - 96.0KiB  / 41.1MiB  eta unknown
# D: 0% - 100.0KiB / 41.1MiB  eta unknown
# D: 0% - 104.0KiB / 41.1MiB  eta unknown
# D: 0% - 108.0KiB / 41.1MiB  eta unknown
# D: 0% - 112.0KiB / 41.1MiB  eta unknown
# D: 0% - 116.0KiB / 41.1MiB  eta unknown
# D: 0% - 120.0KiB / 41.1MiB  eta unknown
# D: 0% - 124.0KiB / 41.1MiB  eta unknown
# D: 0% - 128.0KiB / 41.1MiB  eta unknown
# D: 0% - 132.0KiB / 41.1MiB  eta unknown
# D: 0% - 136.0KiB / 41.1MiB  eta unknown
# D: 0% - 140.0KiB / 41.1MiB  eta unknown
# D: 0% - 144.0KiB / 41.1MiB  eta unknown
# D: 0% - 148.0KiB / 41.1MiB  eta unknown
# D: 0% - 152.0KiB / 41.1MiB  eta unknown
# D: 0% - 156.0KiB / 41.1MiB  eta unknown
# D: 0% - 160.0KiB / 41.1MiB  eta unknown
# D: 0% - 164.0KiB / 41.1MiB  eta unknown
# D: 0% - 168.0KiB / 41.1MiB  eta unknown
# D: 0% - 172.0KiB / 41.1MiB  eta unknown
# D: 0% - 176.0KiB / 41.1MiB  eta unknown
# D: 0% - 180.0KiB / 41.1MiB  eta unknown
# D: 0% - 184.0KiB / 41.1MiB  eta unknown
# D: 0% - 188.0KiB / 41.1MiB  eta unknown
# D: 0% - 192.0KiB / 41.1MiB  eta unknown
# D: 0% - 196.0KiB / 41.1MiB  eta unknown
# D: 0% - 200.0KiB / 41.1MiB  eta unknown
# D: 0% - 204.0KiB / 41.1MiB  eta unknown
# D: 0% - 208.0KiB / 41.1MiB  eta unknown
# D: 0% - 212.0KiB / 41.1MiB  eta unknown
# D: 0% - 216.0KiB / 41.1MiB  eta unknown
# D: 0% - 220.0KiB / 41.1MiB  eta unknown
# D: 0% - 224.0KiB / 41.1MiB  eta unknown
# D: 0% - 228.0KiB / 41.1MiB  eta unknown
# D: 0% - 232.0KiB / 41.1MiB  eta unknown
# D: 0% - 236.0KiB / 41.1MiB  eta unknown
# D: 0% - 240.0KiB / 41.1MiB  eta unknown
# D: 0% - 244.0KiB / 41.1MiB  eta unknown
# D: 0% - 248.0KiB / 41.1MiB  eta unknown
# D: 0% - 252.0KiB / 41.1MiB  eta unknown
# D: 0% - 256.0KiB / 41.1MiB  eta unknown
# D: 0% - 260.0KiB / 41.1MiB  eta unknown
# D: 0% - 264.0KiB / 41.1MiB  eta unknown
# D: 0% - 268.0KiB / 41.1MiB  eta unknown
# D: 0% - 272.0KiB / 41.1MiB  eta unknown
# D: 0% - 276.0KiB / 41.1MiB  eta unknown
# D: 0% - 280.0KiB / 41.1MiB  eta unknown
# D: 0% - 284.0KiB / 41.1MiB  eta unknown
# D: 0% - 288.0KiB / 41.1MiB  eta unknown
# D: 0% - 292.0KiB / 41.1MiB  eta unknown
# D: 0% - 296.0KiB / 41.1MiB  eta unknown
# D: 0% - 300.0KiB / 41.1MiB  eta unknown
# D: 0% - 304.0KiB / 41.1MiB  eta unknown
# D: 0% - 308.0KiB / 41.1MiB  eta unknown
# D: 0% - 312.0KiB / 41.1MiB  eta unknown
# D: 0% - 316.0KiB / 41.1MiB  eta unknown
# D: 0% - 320.0KiB / 41.1MiB  eta unknown
# D: 0% - 324.0KiB / 41.1MiB  eta unknown
# D: 0% - 328.0KiB / 41.1MiB  eta unknown
# D: 0% - 332.0KiB / 41.1MiB  eta unknown
# D: 0% - 336.0KiB / 41.1MiB  eta unknown
# D: 0% - 340.0KiB / 41.1MiB  eta unknown
# D: 0% - 344.0KiB / 41.1MiB  eta unknown
# D: 0% - 348.0KiB / 41.1MiB  eta unknown
# D: 0% - 352.0KiB / 41.1MiB  eta unknown
# D: 0% - 356.0KiB / 41.1MiB  eta unknown
# D: 0% - 360.0KiB / 41.1MiB  eta unknown
# D: 0% - 364.0KiB / 41.1MiB  eta unknown
# D: 0% - 368.0KiB / 41.1MiB  eta unknown
# D: 0% - 372.0KiB / 41.1MiB  eta unknown
# D: 0% - 376.0KiB / 41.1MiB  eta unknown
# D: 0% - 380.0KiB / 41.1MiB  eta unknown
# D: 0% - 384.0KiB / 41.1MiB  eta unknown
# D: 0% - 388.0KiB / 41.1MiB  eta unknown
# D: 0% - 392.0KiB / 41.1MiB  eta unknown
# D: 0% - 396.0KiB / 41.1MiB  eta unknown
# D: 0% - 400.0KiB / 41.1MiB  eta unknown
# D: 0% - 404.0KiB / 41.1MiB  eta unknown
# D: 0% - 408.0KiB / 41.1MiB  eta unknown
# D: 0% - 412.0KiB / 41.1MiB  eta unknown
# D: 0% - 416.0KiB / 41.1MiB  eta unknown
# D: 0% - 420.0KiB / 41.1MiB  eta unknown
# D: 1% - 424.0KiB / 41.1MiB  eta unknown
# D: 1% - 428.0KiB / 41.1MiB  eta unknown
# D: 1% - 432.0KiB / 41.1MiB  eta unknown
# D: 1% - 436.0KiB / 41.1MiB  eta unknown
# D: 1% - 440.0KiB / 41.1MiB  eta unknown
# D: 1% - 444.0KiB / 41.1MiB  eta unknown
# D: 1% - 448.0KiB / 41.1MiB  eta unknown
# D: 1% - 452.0KiB / 41.1MiB  eta unknown
# D: 1% - 456.0KiB / 41.1MiB  eta unknown
# D: 1% - 460.0KiB / 41.1MiB  eta unknown
# D: 1% - 464.0KiB / 41.1MiB  eta unknown
# D: 1% - 468.0KiB / 41.1MiB  eta unknown
# D: 1% - 472.0KiB / 41.1MiB  eta unknown
# D: 1% - 476.0KiB / 41.1MiB  eta unknown
# D: 1% - 480.0KiB / 41.1MiB  eta unknown
# D: 1% - 484.0KiB / 41.1MiB  eta unknown
# D: 1% - 488.0KiB / 41.1MiB  eta unknown
# D: 1% - 492.0KiB / 41.1MiB  eta unknown
# D: 1% - 496.0KiB / 41.1MiB  eta unknown
# D: 1% - 500.0KiB / 41.1MiB  eta unknown
# D: 1% - 504.0KiB / 41.1MiB  eta unknown
# D: 1% - 508.0KiB / 41.1MiB  eta unknown
# D: 1% - 512.0KiB / 41.1MiB  eta unknown
# D: 1% - 516.0KiB / 41.1MiB  eta unknown
# D: 1% - 520.0KiB / 41.1MiB  eta unknown
# D: 1% - 524.0KiB / 41.1MiB  eta unknown
# D: 1% - 528.0KiB / 41.1MiB  eta unknown
# D: 1% - 532.0KiB / 41.1MiB  eta unknown
# D: 1% - 536.0KiB / 41.1MiB  eta unknown
# D: 1% - 540.0KiB / 41.1MiB  eta unknown
# D: 1% - 544.0KiB / 41.1MiB  eta unknown
# D: 1% - 548.0KiB / 41.1MiB  eta unknown
# D: 1% - 552.0KiB / 41.1MiB  eta unknown
# D: 1% - 556.0KiB / 41.1MiB  eta unknown
# D: 1% - 560.0KiB / 41.1MiB  eta unknown
# D: 1% - 564.0KiB / 41.1MiB  eta unknown
# D: 1% - 568.0KiB / 41.1MiB  eta unknown
# D: 1% - 572.0KiB / 41.1MiB  eta unknown
# D: 1% - 576.0KiB / 41.1MiB  eta unknown
# D: 1% - 580.0KiB / 41.1MiB  eta unknown
# D: 1% - 584.0KiB / 41.1MiB  eta unknown
# D: 1% - 588.0KiB / 41.1MiB  eta unknown
# D: 1% - 592.0KiB / 41.1MiB  eta unknown
# D: 1% - 596.0KiB / 41.1MiB  eta unknown
# D: 1% - 600.0KiB / 41.1MiB  eta unknown
# D: 1% - 604.0KiB / 41.1MiB  eta unknown
# D: 1% - 608.0KiB / 41.1MiB  eta unknown
# D: 1% - 612.0KiB / 41.1MiB  eta unknown
# D: 1% - 616.0KiB / 41.1MiB  eta unknown
# D: 1% - 620.0KiB / 41.1MiB  eta unknown
# D: 1% - 624.0KiB / 41.1MiB  eta unknown
# D: 1% - 628.0KiB / 41.1MiB  eta unknown
# D: 1% - 632.0KiB / 41.1MiB  eta unknown
# D: 1% - 636.0KiB / 41.1MiB  eta unknown
# D: 1% - 640.0KiB / 41.1MiB  eta unknown
# D: 1% - 644.0KiB / 41.1MiB  eta unknown
# D: 1% - 648.0KiB / 41.1MiB  eta unknown
# D: 1% - 652.0KiB / 41.1MiB  eta unknown
# D: 1% - 656.0KiB / 41.1MiB  eta unknown
# D: 1% - 660.0KiB / 41.1MiB  eta unknown
# D: 1% - 664.0KiB / 41.1MiB  eta unknown
# D: 1% - 668.0KiB / 41.1MiB  eta unknown
# D: 1% - 672.0KiB / 41.1MiB  eta unknown
# D: 1% - 676.0KiB / 41.1MiB  eta unknown
# D: 1% - 680.0KiB / 41.1MiB  eta unknown
# D: 1% - 684.0KiB / 41.1MiB  eta unknown
# D: 1% - 688.0KiB / 41.1MiB  eta unknown
# D: 1% - 692.0KiB / 41.1MiB  eta unknown
# D: 1% - 696.0KiB / 41.1MiB  eta unknown
# D: 1% - 700.0KiB / 41.1MiB  eta unknown
# D: 1% - 704.0KiB / 41.1MiB  eta unknown
# D: 1% - 708.0KiB / 41.1MiB  eta unknown
# D: 1% - 712.0KiB / 41.1MiB  eta unknown
# D: 1% - 716.0KiB / 41.1MiB  eta unknown
# D: 1% - 720.0KiB / 41.1MiB  eta unknown
# D: 1% - 724.0KiB / 41.1MiB  eta unknown
# D: 1% - 728.0KiB / 41.1MiB  eta unknown
# D: 1% - 732.0KiB / 41.1MiB  eta unknown
# D: 1% - 736.0KiB / 41.1MiB  eta unknown
# D: 1% - 740.0KiB / 41.1MiB  eta unknown
# D: 1% - 744.0KiB / 41.1MiB  eta unknown
# D: 1% - 748.0KiB / 41.1MiB  eta unknown
# D: 1% - 752.0KiB / 41.1MiB  eta unknown
# D: 1% - 756.0KiB / 41.1MiB  eta unknown
# D: 1% - 760.0KiB / 41.1MiB  eta unknown
# D: 1% - 764.0KiB / 41.1MiB  eta unknown
# D: 1% - 768.0KiB / 41.1MiB  eta unknown
# D: 1% - 772.0KiB / 41.1MiB  eta unknown
# D: 1% - 776.0KiB / 41.1MiB  eta unknown
# D: 1% - 780.0KiB / 41.1MiB  eta unknown
# D: 1% - 784.0KiB / 41.1MiB  eta unknown
# D: 1% - 788.0KiB / 41.1MiB  eta unknown
# D: 1% - 792.0KiB / 41.1MiB  eta unknown
# D: 1% - 796.0KiB / 41.1MiB  eta unknown
# D: 1% - 800.0KiB / 41.1MiB  eta unknown
# D: 1% - 804.0KiB / 41.1MiB  eta unknown
# D: 1% - 808.0KiB / 41.1MiB  eta unknown
# D: 1% - 812.0KiB / 41.1MiB  eta unknown
# D: 1% - 816.0KiB / 41.1MiB  eta unknown
# D: 1% - 820.0KiB / 41.1MiB  eta unknown
# D: 1% - 824.0KiB / 41.1MiB  eta unknown
# D: 1% - 828.0KiB / 41.1MiB  eta unknown
# D: 1% - 832.0KiB / 41.1MiB  eta unknown
# D: 1% - 836.0KiB / 41.1MiB  eta unknown
# D: 1% - 840.0KiB / 41.1MiB  eta unknown
# D: 2% - 844.0KiB / 41.1MiB  eta unknown
# D: 2% - 848.0KiB / 41.1MiB  eta unknown
# D: 2% - 852.0KiB / 41.1MiB  eta unknown
# D: 2% - 856.0KiB / 41.1MiB  eta unknown
# D: 2% - 860.0KiB / 41.1MiB  eta unknown
# D: 2% - 864.0KiB / 41.1MiB  eta unknown
# D: 2% - 868.0KiB / 41.1MiB  eta unknown
# D: 2% - 872.0KiB / 41.1MiB  eta unknown
# D: 2% - 876.0KiB / 41.1MiB  eta unknown
# D: 2% - 880.0KiB / 41.1MiB  eta unknown
# D: 2% - 884.0KiB / 41.1MiB  eta unknown
# D: 2% - 888.0KiB / 41.1MiB  eta unknown
# D: 2% - 892.0KiB / 41.1MiB  eta unknown
# D: 2% - 896.0KiB / 41.1MiB  eta unknown
# D: 2% - 900.0KiB / 41.1MiB  eta unknown
# D: 2% - 904.0KiB / 41.1MiB  eta unknown
# D: 2% - 908.0KiB / 41.1MiB  eta unknown
# D: 2% - 912.0KiB / 41.1MiB  eta unknown
# D: 2% - 916.0KiB / 41.1MiB  eta unknown
# D: 2% - 920.0KiB / 41.1MiB  eta unknown
# D: 2% - 924.0KiB / 41.1MiB  eta unknown
# D: 2% - 928.0KiB / 41.1MiB  eta unknown
# D: 2% - 932.0KiB / 41.1MiB  eta unknown
# D: 2% - 936.0KiB / 41.1MiB  eta unknown
# D: 2% - 940.0KiB / 41.1MiB  eta unknown
# D: 2% - 944.0KiB / 41.1MiB  eta unknown
# D: 2% - 948.0KiB / 41.1MiB  eta unknown
# D: 2% - 952.0KiB / 41.1MiB  eta unknown
# D: 2% - 956.0KiB / 41.1MiB  eta unknown
# D: 2% - 960.0KiB / 41.1MiB  eta unknown
# D: 2% - 964.0KiB / 41.1MiB  eta unknown
# D: 2% - 968.0KiB / 41.1MiB  eta unknown
# D: 2% - 972.0KiB / 41.1MiB  eta unknown
# D: 2% - 976.0KiB / 41.1MiB  eta unknown
# D: 2% - 980.0KiB / 41.1MiB  eta unknown
# D: 2% - 984.0KiB / 41.1MiB  eta unknown
# D: 2% - 988.0KiB / 41.1MiB  eta unknown
# D: 2% - 992.0KiB / 41.1MiB  eta unknown
# D: 2% - 996.0KiB / 41.1MiB  eta unknown
# D: 2% -1000.0KiB / 41.1MiB  eta unknown
# D: 2% -1004.0KiB / 41.1MiB  eta unknown
# D: 2% -1008.0KiB / 41.1MiB  eta unknown
# D: 2% -1012.0KiB / 41.1MiB  eta unknown
# D: 2% -1016.0KiB / 41.1MiB  eta unknown
# D: 2% -1020.0KiB / 41.1MiB  eta unknown
# D: 2% -  1.0MiB  / 41.1MiB  eta unknown
# D: 2% -  1.0MiB  / 41.1MiB  eta unknown
# D: 2% -  1.0MiB  / 41.1MiB  eta unknown
# D: 2% -  1.0MiB  / 41.1MiB  eta unknown
# D: 2% -  1.0MiB  / 41.1MiB  eta unknown
# D: 2% -  1.0MiB  / 41.1MiB  eta unknown
# D: 2% -  1.0MiB  / 41.1MiB  eta unknown
# D: 2% -  1.0MiB  / 41.1MiB  eta unknown
# D: 2% -  1.0MiB  / 41.1MiB  eta unknown
# D: 2% -  1.0MiB  / 41.1MiB  eta unknown
# D: 2% -  1.0MiB  / 41.1MiB  eta unknown
# D: 2% -  1.0MiB  / 41.1MiB  eta unknown
# D: 2% -  1.0MiB  / 41.1MiB  eta unknown
# D: 2% -  1.1MiB  / 41.1MiB  eta unknown
# D: 2% -  1.1MiB  / 41.1MiB  eta unknown
# D: 2% -  1.1MiB  / 41.1MiB  eta unknown
# D: 2% -  1.1MiB  / 41.1MiB  eta unknown
# D: 2% -  1.1MiB  / 41.1MiB  eta unknown
# D: 2% -  1.1MiB  / 41.1MiB  eta unknown
# D: 2% -  1.1MiB  / 41.1MiB  eta unknown
# D: 2% -  1.1MiB  / 41.1MiB  eta unknown
# D: 2% -  1.1MiB  / 41.1MiB  eta unknown
# D: 2% -  1.1MiB  / 41.1MiB  eta unknown
# D: 2% -  1.1MiB  / 41.1MiB  eta unknown
# D: 2% -  1.1MiB  / 41.1MiB  eta unknown
# D: 2% -  1.1MiB  / 41.1MiB  eta unknown
# D: 2% -  1.1MiB  / 41.1MiB  eta unknown
# D: 2% -  1.1MiB  / 41.1MiB  eta unknown
# D: 2% -  1.1MiB  / 41.1MiB  eta unknown
# D: 2% -  1.1MiB  / 41.1MiB  eta unknown
# D: 2% -  1.1MiB  / 41.1MiB  eta unknown
# D: 2% -  1.1MiB  / 41.1MiB  eta unknown
# D: 2% -  1.1MiB  / 41.1MiB  eta unknown
# D: 2% -  1.1MiB  / 41.1MiB  eta unknown
# D: 2% -  1.1MiB  / 41.1MiB  eta unknown
# D: 2% -  1.1MiB  / 41.1MiB  eta unknown
# D: 2% -  1.1MiB  / 41.1MiB  eta unknown
# D: 2% -  1.1MiB  / 41.1MiB  eta unknown
# D: 2% -  1.1MiB  / 41.1MiB  eta unknown
# D: 2% -  1.2MiB  / 41.1MiB  eta unknown
# D: 2% -  1.2MiB  / 41.1MiB  eta unknown
# D: 2% -  1.2MiB  / 41.1MiB  eta unknown
# D: 2% -  1.2MiB  / 41.1MiB  eta unknown
# D: 2% -  1.2MiB  / 41.1MiB  eta unknown
# D: 2% -  1.2MiB  / 41.1MiB  eta unknown
# D: 2% -  1.2MiB  / 41.1MiB  eta unknown
# D: 2% -  1.2MiB  / 41.1MiB  eta unknown
# D: 2% -  1.2MiB  / 41.1MiB  eta unknown
# D: 2% -  1.2MiB  / 41.1MiB  eta unknown
# D: 2% -  1.2MiB  / 41.1MiB  eta unknown
# D: 2% -  1.2MiB  / 41.1MiB  eta unknown
# D: 2% -  1.2MiB  / 41.1MiB  eta unknown
# D: 2% -  1.2MiB  / 41.1MiB  eta unknown
# D: 2% -  1.2MiB  / 41.1MiB  eta unknown
# D: 2% -  1.2MiB  / 41.1MiB  eta unknown
# D: 2% -  1.2MiB  / 41.1MiB  eta unknown
# D: 2% -  1.2MiB  / 41.1MiB  eta unknown
# D: 2% -  1.2MiB  / 41.1MiB  eta unknown
# D: 2% -  1.2MiB  / 41.1MiB  eta unknown
# D: 2% -  1.2MiB  / 41.1MiB  eta unknown
# D: 3% -  1.2MiB  / 41.1MiB  eta unknown
# D: 3% -  1.2MiB  / 41.1MiB  eta unknown
# D: 3% -  1.2MiB  / 41.1MiB  eta unknown
# D: 3% -  1.2MiB  / 41.1MiB  eta unknown
# D: 3% -  1.2MiB  / 41.1MiB  eta unknown
# D: 3% -  1.3MiB  / 41.1MiB  eta unknown
# D: 3% -  1.3MiB  / 41.1MiB  eta unknown
# D: 3% -  1.3MiB  / 41.1MiB  eta unknown
# D: 3% -  1.3MiB  / 41.1MiB  eta unknown
# D: 3% -  1.3MiB  / 41.1MiB  eta unknown
# D: 3% -  1.3MiB  / 41.1MiB  eta unknown
# D: 3% -  1.3MiB  / 41.1MiB  eta unknown
# D: 3% -  1.3MiB  / 41.1MiB  eta unknown
# D: 3% -  1.3MiB  / 41.1MiB  eta unknown
# D: 3% -  1.3MiB  / 41.1MiB  eta unknown
# D: 3% -  1.3MiB  / 41.1MiB  eta unknown
# D: 3% -  1.3MiB  / 41.1MiB  eta unknown
# D: 3% -  1.3MiB  / 41.1MiB  eta unknown
# D: 3% -  1.3MiB  / 41.1MiB  eta unknown
# D: 3% -  1.3MiB  / 41.1MiB  eta unknown
# D: 3% -  1.3MiB  / 41.1MiB  eta unknown
# D: 3% -  1.3MiB  / 41.1MiB  eta unknown
# D: 3% -  1.3MiB  / 41.1MiB  eta unknown
# D: 3% -  1.3MiB  / 41.1MiB  eta unknown
# D: 3% -  1.3MiB  / 41.1MiB  eta unknown
# D: 3% -  1.3MiB  / 41.1MiB  eta unknown
# D: 3% -  1.3MiB  / 41.1MiB  eta unknown
# D: 3% -  1.3MiB  / 41.1MiB  eta unknown
# D: 3% -  1.3MiB  / 41.1MiB  eta unknown
# D: 3% -  1.3MiB  / 41.1MiB  eta unknown
# D: 3% -  1.4MiB  / 41.1MiB  eta unknown
# D: 3% -  1.4MiB  / 41.1MiB  eta unknown
# D: 3% -  1.4MiB  / 41.1MiB  eta unknown
# D: 3% -  1.4MiB  / 41.1MiB  eta unknown
# D: 3% -  1.4MiB  / 41.1MiB  eta unknown
# D: 3% -  1.4MiB  / 41.1MiB  eta unknown
# D: 3% -  1.4MiB  / 41.1MiB  eta unknown
# D: 3% -  1.4MiB  / 41.1MiB  eta unknown
# D: 3% -  1.4MiB  / 41.1MiB  eta unknown
# D: 3% -  1.4MiB  / 41.1MiB  eta unknown
# D: 3% -  1.4MiB  / 41.1MiB  eta unknown
# D: 3% -  1.4MiB  / 41.1MiB  eta unknown
# D: 3% -  1.4MiB  / 41.1MiB  eta unknown
# D: 3% -  1.4MiB  / 41.1MiB  eta unknown
# D: 3% -  1.4MiB  / 41.1MiB  eta unknown
# D: 3% -  1.4MiB  / 41.1MiB  eta unknown
# D: 3% -  1.4MiB  / 41.1MiB  eta unknown
# D: 3% -  1.4MiB  / 41.1MiB  eta unknown
# D: 3% -  1.4MiB  / 41.1MiB  eta unknown
# D: 3% -  1.4MiB  / 41.1MiB  eta unknown
# D: 3% -  1.4MiB  / 41.1MiB  eta unknown
# D: 3% -  1.4MiB  / 41.1MiB  eta unknown
# D: 3% -  1.4MiB  / 41.1MiB  eta unknown
# D: 3% -  1.4MiB  / 41.1MiB  eta unknown
# D: 3% -  1.4MiB  / 41.1MiB  eta unknown
# D: 3% -  1.4MiB  / 41.1MiB  eta unknown
# D: 3% -  1.5MiB  / 41.1MiB  eta unknown
# D: 3% -  1.5MiB  / 41.1MiB  eta unknown
# D: 3% -  1.5MiB  / 41.1MiB  eta unknown
# D: 3% -  1.5MiB  / 41.1MiB  eta unknown
# D: 3% -  1.5MiB  / 41.1MiB  eta unknown
# D: 3% -  1.5MiB  / 41.1MiB  eta unknown
# D: 3% -  1.5MiB  / 41.1MiB  eta unknown
# D: 3% -  1.5MiB  / 41.1MiB  eta unknown
# D: 3% -  1.5MiB  / 41.1MiB  eta unknown
# D: 3% -  1.5MiB  / 41.1MiB  eta unknown
# D: 3% -  1.5MiB  / 41.1MiB  eta unknown
# D: 3% -  1.5MiB  / 41.1MiB  eta unknown
# D: 3% -  1.5MiB  / 41.1MiB  eta unknown
# D: 3% -  1.5MiB  / 41.1MiB  eta unknown
# D: 3% -  1.5MiB  / 41.1MiB  eta unknown
# D: 3% -  1.5MiB  / 41.1MiB  eta unknown
# D: 3% -  1.5MiB  / 41.1MiB  eta unknown
# D: 3% -  1.5MiB  / 41.1MiB  eta unknown
# D: 3% -  1.5MiB  / 41.1MiB  eta unknown
# D: 3% -  1.5MiB  / 41.1MiB  eta unknown
# D: 3% -  1.5MiB  / 41.1MiB  eta unknown
# D: 3% -  1.5MiB  / 41.1MiB  eta unknown
# D: 3% -  1.5MiB  / 41.1MiB  eta unknown
# D: 3% -  1.5MiB  / 41.1MiB  eta unknown
# D: 3% -  1.5MiB  / 41.1MiB  eta unknown
# D: 3% -  1.6MiB  / 41.1MiB  eta unknown
# D: 3% -  1.6MiB  / 41.1MiB  eta unknown
# D: 3% -  1.6MiB  / 41.1MiB  eta unknown
# D: 3% -  1.6MiB  / 41.1MiB  eta unknown
# D: 3% -  1.6MiB  / 41.1MiB  eta unknown
# D: 3% -  1.6MiB  / 41.1MiB  eta unknown
# D: 3% -  1.6MiB  / 41.1MiB  eta unknown
# D: 3% -  1.6MiB  / 41.1MiB  eta unknown
# D: 3% -  1.6MiB  / 41.1MiB  eta unknown
# D: 3% -  1.6MiB  / 41.1MiB  eta unknown
# D: 3% -  1.6MiB  / 41.1MiB  eta unknown
# D: 3% -  1.6MiB  / 41.1MiB  eta unknown
# D: 3% -  1.6MiB  / 41.1MiB  eta unknown
# D: 3% -  1.6MiB  / 41.1MiB  eta unknown
# D: 3% -  1.6MiB  / 41.1MiB  eta unknown
# D: 3% -  1.6MiB  / 41.1MiB  eta unknown
# D: 3% -  1.6MiB  / 41.1MiB  eta unknown
# D: 3% -  1.6MiB  / 41.1MiB  eta unknown
# D: 3% -  1.6MiB  / 41.1MiB  eta unknown
# D: 3% -  1.6MiB  / 41.1MiB  eta unknown
# D: 3% -  1.6MiB  / 41.1MiB  eta unknown
# D: 3% -  1.6MiB  / 41.1MiB  eta unknown
# D: 3% -  1.6MiB  / 41.1MiB  eta unknown
# D: 3% -  1.6MiB  / 41.1MiB  eta unknown
# D: 4% -  1.6MiB  / 41.1MiB  eta unknown
# D: 4% -  1.6MiB  / 41.1MiB  eta unknown
# D: 4% -  1.7MiB  / 41.1MiB  eta unknown
# D: 4% -  1.7MiB  / 41.1MiB  eta unknown
# D: 4% -  1.7MiB  / 41.1MiB  eta unknown
# D: 4% -  1.7MiB  / 41.1MiB  eta unknown
# D: 4% -  1.7MiB  / 41.1MiB  eta unknown
# D: 4% -  1.7MiB  / 41.1MiB  eta unknown
# D: 4% -  1.7MiB  / 41.1MiB  eta unknown
# D: 4% -  1.7MiB  / 41.1MiB  eta unknown
# D: 4% -  1.7MiB  / 41.1MiB  eta unknown
# D: 4% -  1.7MiB  / 41.1MiB  eta unknown
# D: 4% -  1.7MiB  / 41.1MiB  eta unknown
# D: 4% -  1.7MiB  / 41.1MiB  eta unknown
# D: 4% -  1.7MiB  / 41.1MiB  eta unknown
# D: 4% -  1.7MiB  / 41.1MiB  eta unknown
# D: 4% -  1.7MiB  / 41.1MiB  eta unknown
# D: 4% -  1.7MiB  / 41.1MiB  eta unknown
# D: 4% -  1.7MiB  / 41.1MiB  eta unknown
# D: 4% -  1.7MiB  / 41.1MiB  eta unknown
# D: 4% -  1.7MiB  / 41.1MiB  eta unknown
# D: 4% -  1.7MiB  / 41.1MiB  eta unknown
# D: 4% -  1.7MiB  / 41.1MiB  eta unknown
# D: 4% -  1.7MiB  / 41.1MiB  eta unknown
# D: 4% -  1.7MiB  / 41.1MiB  eta unknown
# D: 4% -  1.7MiB  / 41.1MiB  eta unknown
# D: 4% -  1.7MiB  / 41.1MiB  eta unknown
# D: 4% -  1.8MiB  / 41.1MiB  eta unknown
# D: 4% -  1.8MiB  / 41.1MiB  eta unknown
# D: 4% -  1.8MiB  / 41.1MiB  eta unknown
# D: 4% -  1.8MiB  / 41.1MiB  eta unknown
# D: 4% -  1.8MiB  / 41.1MiB  eta unknown
# D: 4% -  1.8MiB  / 41.1MiB  eta unknown
# D: 4% -  1.8MiB  / 41.1MiB  eta unknown
# D: 4% -  1.8MiB  / 41.1MiB  eta unknown
# D: 4% -  1.8MiB  / 41.1MiB  eta unknown
# D: 4% -  1.8MiB  / 41.1MiB  eta unknown
# D: 4% -  1.8MiB  / 41.1MiB  eta unknown
# D: 4% -  1.8MiB  / 41.1MiB  eta unknown
# D: 4% -  1.8MiB  / 41.1MiB  eta unknown
# D: 4% -  1.8MiB  / 41.1MiB  eta unknown
# D: 4% -  1.8MiB  / 41.1MiB  eta unknown
# D: 4% -  1.8MiB  / 41.1MiB  eta unknown
# D: 4% -  1.8MiB  / 41.1MiB  eta unknown
# D: 4% -  1.8MiB  / 41.1MiB  eta unknown
# D: 4% -  1.8MiB  / 41.1MiB  eta unknown
# D: 4% -  1.8MiB  / 41.1MiB  eta unknown
# D: 4% -  1.8MiB  / 41.1MiB  eta unknown
# D: 4% -  1.8MiB  / 41.1MiB  eta unknown
# D: 4% -  1.8MiB  / 41.1MiB  eta unknown
# D: 4% -  1.8MiB  / 41.1MiB  eta unknown
# D: 4% -  1.8MiB  / 41.1MiB  eta unknown
# D: 4% -  1.8MiB  / 41.1MiB  eta unknown
# D: 4% -  1.9MiB  / 41.1MiB  eta unknown
# D: 4% -  1.9MiB  / 41.1MiB  eta unknown
# D: 4% -  1.9MiB  / 41.1MiB  eta unknown
# D: 4% -  1.9MiB  / 41.1MiB  eta unknown
# D: 4% -  1.9MiB  / 41.1MiB  eta unknown
# D: 4% -  1.9MiB  / 41.1MiB  eta unknown
# D: 4% -  1.9MiB  / 41.1MiB  eta unknown
# D: 4% -  1.9MiB  / 41.1MiB  eta unknown
# D: 4% -  1.9MiB  / 41.1MiB  eta unknown
# D: 4% -  1.9MiB  / 41.1MiB  eta unknown
# D: 4% -  1.9MiB  / 41.1MiB  eta unknown
# D: 4% -  1.9MiB  / 41.1MiB  eta unknown
# D: 4% -  1.9MiB  / 41.1MiB  eta unknown
# D: 4% -  1.9MiB  / 41.1MiB  eta unknown
# D: 4% -  1.9MiB  / 41.1MiB  eta unknown
# D: 4% -  1.9MiB  / 41.1MiB  eta unknown
# D: 4% -  1.9MiB  / 41.1MiB  eta unknown
# D: 4% -  1.9MiB  / 41.1MiB  eta unknown
# D: 4% -  1.9MiB  / 41.1MiB  eta unknown
# D: 4% -  1.9MiB  / 41.1MiB  eta unknown
# D: 4% -  1.9MiB  / 41.1MiB  eta unknown
# D: 4% -  1.9MiB  / 41.1MiB  eta unknown
# D: 4% -  1.9MiB  / 41.1MiB  eta unknown
# D: 4% -  1.9MiB  / 41.1MiB  eta unknown
# D: 4% -  1.9MiB  / 41.1MiB  eta unknown
# D: 4% -  1.9MiB  / 41.1MiB  eta unknown
# D: 4% -  2.0MiB  / 41.1MiB  eta unknown
# D: 4% -  2.0MiB  / 41.1MiB  eta unknown
# D: 4% -  2.0MiB  / 41.1MiB  eta unknown
# D: 4% -  2.0MiB  / 41.1MiB  eta unknown
# D: 4% -  2.0MiB  / 41.1MiB  eta unknown
# D: 4% -  2.0MiB  / 41.1MiB  eta unknown
# D: 4% -  2.0MiB  / 41.1MiB  eta unknown
# D: 4% -  2.0MiB  / 41.1MiB  eta unknown
# D: 4% -  2.0MiB  / 41.1MiB  eta unknown
# D: 4% -  2.0MiB  / 41.1MiB  eta unknown
# D: 4% -  2.0MiB  / 41.1MiB  eta unknown
# D: 4% -  2.0MiB  / 41.1MiB  eta unknown
# D: 4% -  2.0MiB  / 41.1MiB  eta unknown
# D: 4% -  2.0MiB  / 41.1MiB  eta unknown
# D: 4% -  2.0MiB  / 41.1MiB  eta unknown
# D: 4% -  2.0MiB  / 41.1MiB  eta unknown
# D: 4% -  2.0MiB  / 41.1MiB  eta unknown
# D: 4% -  2.0MiB  / 41.1MiB  eta unknown
# D: 4% -  2.0MiB  / 41.1MiB  eta unknown
# D: 4% -  2.0MiB  / 41.1MiB  eta unknown
# D: 4% -  2.0MiB  / 41.1MiB  eta unknown
# D: 4% -  2.0MiB  / 41.1MiB  eta unknown
# D: 4% -  2.0MiB  / 41.1MiB  eta unknown
# D: 4% -  2.0MiB  / 41.1MiB  eta unknown
# D: 4% -  2.0MiB  / 41.1MiB  eta unknown
# D: 4% -  2.1MiB  / 41.1MiB  eta unknown
# D: 5% -  2.1MiB  / 41.1MiB  eta unknown
# D: 5% -  2.1MiB  / 41.1MiB  eta unknown
# D: 5% -  2.1MiB  / 41.1MiB  eta unknown
# D: 5% -  2.1MiB  / 41.1MiB  eta unknown
# D: 5% -  2.1MiB  / 41.1MiB  eta unknown
# D: 5% -  2.1MiB  / 41.1MiB  eta unknown
# D: 5% -  2.1MiB  / 41.1MiB  eta unknown
# D: 5% -  2.1MiB  / 41.1MiB  eta unknown
# D: 5% -  2.1MiB  / 41.1MiB  eta unknown
# D: 5% -  2.1MiB  / 41.1MiB  eta unknown
# D: 5% -  2.1MiB  / 41.1MiB  eta unknown
# D: 5% -  2.1MiB  / 41.1MiB  eta unknown
# D: 5% -  2.1MiB  / 41.1MiB  eta unknown
# D: 5% -  2.1MiB  / 41.1MiB  eta unknown
# D: 5% -  2.1MiB  / 41.1MiB  eta unknown
# D: 5% -  2.1MiB  / 41.1MiB  eta unknown
# D: 5% -  2.1MiB  / 41.1MiB  eta unknown
# D: 5% -  2.1MiB  / 41.1MiB  eta unknown
# D: 5% -  2.1MiB  / 41.1MiB  eta unknown
# D: 5% -  2.1MiB  / 41.1MiB  eta unknown
# D: 5% -  2.1MiB  / 41.1MiB  eta unknown
# D: 5% -  2.1MiB  / 41.1MiB  eta unknown
# D: 5% -  2.1MiB  / 41.1MiB  eta unknown
# D: 5% -  2.1MiB  / 41.1MiB  eta unknown
# D: 5% -  2.1MiB  / 41.1MiB  eta unknown
# D: 5% -  2.2MiB  / 41.1MiB  eta unknown
# D: 5% -  2.2MiB  / 41.1MiB  eta unknown
# D: 5% -  2.2MiB  / 41.1MiB  eta unknown
# D: 5% -  2.2MiB  / 41.1MiB  eta unknown
# D: 5% -  2.2MiB  / 41.1MiB  eta unknown
# D: 5% -  2.2MiB  / 41.1MiB  eta unknown
# D: 5% -  2.2MiB  / 41.1MiB  eta unknown
# D: 5% -  2.2MiB  / 41.1MiB  eta unknown
# D: 5% -  2.2MiB  / 41.1MiB  eta unknown
# D: 5% -  2.2MiB  / 41.1MiB  eta unknown
# D: 5% -  2.2MiB  / 41.1MiB  eta unknown
# D: 5% -  2.2MiB  / 41.1MiB  eta unknown
# D: 5% -  2.2MiB  / 41.1MiB  eta unknown
# D: 5% -  2.2MiB  / 41.1MiB  eta unknown
# D: 5% -  2.2MiB  / 41.1MiB  eta unknown
# D: 5% -  2.2MiB  / 41.1MiB  eta unknown
# D: 5% -  2.2MiB  / 41.1MiB  eta unknown
# D: 5% -  2.2MiB  / 41.1MiB  eta unknown
# D: 5% -  2.2MiB  / 41.1MiB  eta unknown
# D: 5% -  2.2MiB  / 41.1MiB  eta unknown
# D: 5% -  2.2MiB  / 41.1MiB  eta unknown
# D: 5% -  2.2MiB  / 41.1MiB  eta unknown
# D: 5% -  2.2MiB  / 41.1MiB  eta unknown
# D: 5% -  2.2MiB  / 41.1MiB  eta unknown
# D: 5% -  2.2MiB  / 41.1MiB  eta unknown
# D: 5% -  2.2MiB  / 41.1MiB  eta unknown
# D: 5% -  2.3MiB  / 41.1MiB  eta unknown
# D: 5% -  2.3MiB  / 41.1MiB  eta unknown
# D: 5% -  2.3MiB  / 41.1MiB  eta unknown
# D: 5% -  2.3MiB  / 41.1MiB  eta unknown
# D: 5% -  2.3MiB  / 41.1MiB  eta unknown
# D: 5% -  2.3MiB  / 41.1MiB  eta unknown
# D: 5% -  2.3MiB  / 41.1MiB  eta unknown
# D: 5% -  2.3MiB  / 41.1MiB  eta unknown
# D: 5% -  2.3MiB  / 41.1MiB  eta unknown
# D: 5% -  2.3MiB  / 41.1MiB  eta unknown
# D: 5% -  2.3MiB  / 41.1MiB  eta unknown
# D: 5% -  2.3MiB  / 41.1MiB  eta unknown
# D: 5% -  2.3MiB  / 41.1MiB  eta unknown
# D: 5% -  2.3MiB  / 41.1MiB  eta unknown
# D: 5% -  2.3MiB  / 41.1MiB  eta unknown
# D: 5% -  2.3MiB  / 41.1MiB  eta unknown
# D: 5% -  2.3MiB  / 41.1MiB  eta unknown
# D: 5% -  2.3MiB  / 41.1MiB  eta unknown
# D: 5% -  2.3MiB  / 41.1MiB  eta unknown
# D: 5% -  2.3MiB  / 41.1MiB  eta unknown
# D: 5% -  2.3MiB  / 41.1MiB  eta unknown
# D: 5% -  2.3MiB  / 41.1MiB  eta unknown
# D: 5% -  2.3MiB  / 41.1MiB  eta unknown
# D: 5% -  2.3MiB  / 41.1MiB  eta unknown
# D: 5% -  2.3MiB  / 41.1MiB  eta unknown
# D: 5% -  2.4MiB  / 41.1MiB  eta unknown
# D: 5% -  2.4MiB  / 41.1MiB  eta unknown
# D: 5% -  2.4MiB  / 41.1MiB  eta unknown
# D: 5% -  2.4MiB  / 41.1MiB  eta unknown
# D: 5% -  2.4MiB  / 41.1MiB  eta unknown
# D: 5% -  2.4MiB  / 41.1MiB  eta unknown
# D: 5% -  2.4MiB  / 41.1MiB  eta unknown
# D: 5% -  2.4MiB  / 41.1MiB  eta unknown
# D: 5% -  2.4MiB  / 41.1MiB  eta unknown
# D: 5% -  2.4MiB  / 41.1MiB  eta unknown
# D: 5% -  2.4MiB  / 41.1MiB  eta unknown
# D: 5% -  2.4MiB  / 41.1MiB  eta unknown
# D: 5% -  2.4MiB  / 41.1MiB  eta unknown
# D: 5% -  2.4MiB  / 41.1MiB  eta unknown
# D: 5% -  2.4MiB  / 41.1MiB  eta unknown
# D: 5% -  2.4MiB  / 41.1MiB  eta unknown
# D: 5% -  2.4MiB  / 41.1MiB  eta unknown
# D: 5% -  2.4MiB  / 41.1MiB  eta unknown
# D: 5% -  2.4MiB  / 41.1MiB  eta unknown
# D: 5% -  2.4MiB  / 41.1MiB  eta unknown
# D: 5% -  2.4MiB  / 41.1MiB  eta unknown
# D: 5% -  2.4MiB  / 41.1MiB  eta unknown
# D: 5% -  2.4MiB  / 41.1MiB  eta unknown
# D: 5% -  2.4MiB  / 41.1MiB  eta unknown
# D: 5% -  2.4MiB  / 41.1MiB  eta unknown
# D: 5% -  2.4MiB  / 41.1MiB  eta unknown
# D: 5% -  2.5MiB  / 41.1MiB  eta unknown
# D: 5% -  2.5MiB  / 41.1MiB  eta unknown
# D: 5% -  2.5MiB  / 41.1MiB  eta unknown
# D: 5% -  2.5MiB  / 41.1MiB  eta unknown
# D: 6% -  2.5MiB  / 41.1MiB  eta unknown
# D: 6% -  2.5MiB  / 41.1MiB  eta unknown
# D: 6% -  2.5MiB  / 41.1MiB  eta unknown
# D: 6% -  2.5MiB  / 41.1MiB  eta unknown
# D: 6% -  2.5MiB  / 41.1MiB  eta unknown
# D: 6% -  2.5MiB  / 41.1MiB  eta unknown
# D: 6% -  2.5MiB  / 41.1MiB  eta unknown
# D: 6% -  2.5MiB  / 41.1MiB  eta unknown
# D: 6% -  2.5MiB  / 41.1MiB  eta unknown
# D: 6% -  2.5MiB  / 41.1MiB  eta unknown
# D: 6% -  2.5MiB  / 41.1MiB  eta unknown
# D: 6% -  2.5MiB  / 41.1MiB  eta unknown
# D: 6% -  2.5MiB  / 41.1MiB  eta unknown
# D: 6% -  2.5MiB  / 41.1MiB  eta unknown
# D: 6% -  2.5MiB  / 41.1MiB  eta unknown
# D: 6% -  2.5MiB  / 41.1MiB  eta unknown
# D: 6% -  2.5MiB  / 41.1MiB  eta unknown
# D: 6% -  2.5MiB  / 41.1MiB  eta unknown
# D: 6% -  2.5MiB  / 41.1MiB  eta unknown
# D: 6% -  2.5MiB  / 41.1MiB  eta unknown
# D: 6% -  2.5MiB  / 41.1MiB  eta unknown
# D: 6% -  2.6MiB  / 41.1MiB  eta unknown
# D: 6% -  2.6MiB  / 41.1MiB  eta unknown
# D: 6% -  2.6MiB  / 41.1MiB  eta unknown
# D: 6% -  2.6MiB  / 41.1MiB  eta unknown
# D: 6% -  2.6MiB  / 41.1MiB  eta unknown
# D: 6% -  2.6MiB  / 41.1MiB  eta unknown
# D: 6% -  2.6MiB  / 41.1MiB  eta unknown
# D: 6% -  2.6MiB  / 41.1MiB  eta unknown
# D: 6% -  2.6MiB  / 41.1MiB  eta unknown
# D: 6% -  2.6MiB  / 41.1MiB  eta unknown
# D: 6% -  2.6MiB  / 41.1MiB  eta unknown
# D: 6% -  2.6MiB  / 41.1MiB  eta unknown
# D: 6% -  2.6MiB  / 41.1MiB  eta unknown
# D: 6% -  2.6MiB  / 41.1MiB  eta unknown
# D: 6% -  2.6MiB  / 41.1MiB  eta unknown
# D: 6% -  2.6MiB  / 41.1MiB  eta unknown
# D: 6% -  2.6MiB  / 41.1MiB  eta unknown
# D: 6% -  2.6MiB  / 41.1MiB  eta unknown
# D: 6% -  2.6MiB  / 41.1MiB  eta unknown
# D: 6% -  2.6MiB  / 41.1MiB  eta unknown
# D: 6% -  2.6MiB  / 41.1MiB  eta unknown
# D: 6% -  2.6MiB  / 41.1MiB  eta unknown
# D: 6% -  2.6MiB  / 41.1MiB  eta unknown
# D: 6% -  2.6MiB  / 41.1MiB  eta unknown
# D: 6% -  2.6MiB  / 41.1MiB  eta unknown
# D: 6% -  2.6MiB  / 41.1MiB  eta unknown
# D: 6% -  2.7MiB  / 41.1MiB  eta unknown
# D: 6% -  2.7MiB  / 41.1MiB  eta unknown
# D: 6% -  2.7MiB  / 41.1MiB  eta unknown
# D: 6% -  2.7MiB  / 41.1MiB  eta unknown
# D: 6% -  2.7MiB  / 41.1MiB  eta unknown
# D: 6% -  2.7MiB  / 41.1MiB  eta unknown
# D: 6% -  2.7MiB  / 41.1MiB  eta unknown
# D: 6% -  2.7MiB  / 41.1MiB  eta unknown
# D: 6% -  2.7MiB  / 41.1MiB  eta unknown
# D: 6% -  2.7MiB  / 41.1MiB  eta unknown
# D: 6% -  2.7MiB  / 41.1MiB  eta unknown
# D: 6% -  2.7MiB  / 41.1MiB  eta unknown
# D: 6% -  2.7MiB  / 41.1MiB  eta unknown
# D: 6% -  2.7MiB  / 41.1MiB  eta unknown
# D: 6% -  2.7MiB  / 41.1MiB  eta unknown
# D: 6% -  2.7MiB  / 41.1MiB  eta unknown
# D: 6% -  2.7MiB  / 41.1MiB  eta unknown
# D: 6% -  2.7MiB  / 41.1MiB  eta unknown
# D: 6% -  2.7MiB  / 41.1MiB  eta unknown
# D: 6% -  2.7MiB  / 41.1MiB  eta unknown
# D: 6% -  2.7MiB  / 41.1MiB  eta unknown
# D: 6% -  2.7MiB  / 41.1MiB  eta unknown
# D: 6% -  2.7MiB  / 41.1MiB  eta unknown
# D: 6% -  2.7MiB  / 41.1MiB  eta unknown
# D: 6% -  2.7MiB  / 41.1MiB  eta unknown
# D: 6% -  2.8MiB  / 41.1MiB  eta unknown
# D: 6% -  2.8MiB  / 41.1MiB  eta unknown
# D: 6% -  2.8MiB  / 41.1MiB  eta unknown
# D: 6% -  2.8MiB  / 41.1MiB  eta unknown
# D: 6% -  2.8MiB  / 41.1MiB  eta unknown
# D: 6% -  2.8MiB  / 41.1MiB  eta unknown
# D: 6% -  2.8MiB  / 41.1MiB  eta unknown
# D: 6% -  2.8MiB  / 41.1MiB  eta unknown
# D: 6% -  2.8MiB  / 41.1MiB  eta unknown
# D: 6% -  2.8MiB  / 41.1MiB  eta unknown
# D: 6% -  2.8MiB  / 41.1MiB  eta unknown
# D: 6% -  2.8MiB  / 41.1MiB  eta unknown
# D: 6% -  2.8MiB  / 41.1MiB  eta unknown
# D: 6% -  2.8MiB  / 41.1MiB  eta unknown
# D: 6% -  2.8MiB  / 41.1MiB  eta unknown
# D: 6% -  2.8MiB  / 41.1MiB  eta unknown
# D: 6% -  2.8MiB  / 41.1MiB  eta unknown
# D: 6% -  2.8MiB  / 41.1MiB  eta unknown
# D: 6% -  2.8MiB  / 41.1MiB  eta unknown
# D: 6% -  2.8MiB  / 41.1MiB  eta unknown
# D: 6% -  2.8MiB  / 41.1MiB  eta unknown
# D: 6% -  2.8MiB  / 41.1MiB  eta unknown
# D: 6% -  2.8MiB  / 41.1MiB  eta unknown
# D: 6% -  2.8MiB  / 41.1MiB  eta unknown
# D: 6% -  2.8MiB  / 41.1MiB  eta unknown
# D: 6% -  2.8MiB  / 41.1MiB  eta unknown
# D: 6% -  2.9MiB  / 41.1MiB  eta unknown
# D: 6% -  2.9MiB  / 41.1MiB  eta unknown
# D: 6% -  2.9MiB  / 41.1MiB  eta unknown
# D: 6% -  2.9MiB  / 41.1MiB  eta unknown
# D: 6% -  2.9MiB  / 41.1MiB  eta unknown
# D: 6% -  2.9MiB  / 41.1MiB  eta unknown
# D: 6% -  2.9MiB  / 41.1MiB  eta unknown
# D: 7% -  2.9MiB  / 41.1MiB  eta unknown
# D: 7% -  2.9MiB  / 41.1MiB  eta unknown
# D: 7% -  2.9MiB  / 41.1MiB  eta unknown
# D: 7% -  2.9MiB  / 41.1MiB  eta unknown
# D: 7% -  2.9MiB  / 41.1MiB  eta unknown
# D: 7% -  2.9MiB  / 41.1MiB  eta unknown
# D: 7% -  2.9MiB  / 41.1MiB  eta unknown
# D: 7% -  2.9MiB  / 41.1MiB  eta unknown
# D: 7% -  2.9MiB  / 41.1MiB  eta unknown
# D: 7% -  2.9MiB  / 41.1MiB  eta unknown
# D: 7% -  2.9MiB  / 41.1MiB  eta unknown
# D: 7% -  2.9MiB  / 41.1MiB  eta unknown
# D: 7% -  2.9MiB  / 41.1MiB  eta unknown
# D: 7% -  2.9MiB  / 41.1MiB  eta unknown
# D: 7% -  2.9MiB  / 41.1MiB  eta unknown
# D: 7% -  2.9MiB  / 41.1MiB  eta unknown
# D: 7% -  2.9MiB  / 41.1MiB  eta unknown
# D: 7% -  2.9MiB  / 41.1MiB  eta unknown
# D: 7% -  2.9MiB  / 41.1MiB  eta unknown
# D: 7% -  3.0MiB  / 41.1MiB  eta unknown
# D: 7% -  3.0MiB  / 41.1MiB  eta unknown
# D: 7% -  3.0MiB  / 41.1MiB  eta unknown
# D: 7% -  3.0MiB  / 41.1MiB  eta unknown
# D: 7% -  3.0MiB  / 41.1MiB  eta unknown
# D: 7% -  3.0MiB  / 41.1MiB  eta unknown
# D: 7% -  3.0MiB  / 41.1MiB  eta unknown
# D: 7% -  3.0MiB  / 41.1MiB  eta unknown
# D: 7% -  3.0MiB  / 41.1MiB  eta unknown
# D: 7% -  3.0MiB  / 41.1MiB  eta unknown
# D: 7% -  3.0MiB  / 41.1MiB  eta unknown
# D: 7% -  3.0MiB  / 41.1MiB  eta unknown
# D: 7% -  3.0MiB  / 41.1MiB  eta unknown
# D: 7% -  3.0MiB  / 41.1MiB  eta unknown
# D: 7% -  3.0MiB  / 41.1MiB  eta unknown
# D: 7% -  3.0MiB  / 41.1MiB  eta unknown
# D: 7% -  3.0MiB  / 41.1MiB  eta unknown
# D: 7% -  3.0MiB  / 41.1MiB  eta unknown
# D: 7% -  3.0MiB  / 41.1MiB  eta unknown
# D: 7% -  3.0MiB  / 41.1MiB  eta unknown
# D: 7% -  3.0MiB  / 41.1MiB  eta unknown
# D: 7% -  3.0MiB  / 41.1MiB  eta unknown
# D: 7% -  3.0MiB  / 41.1MiB  eta unknown
# D: 7% -  3.0MiB  / 41.1MiB  eta unknown
# D: 7% -  3.0MiB  / 41.1MiB  eta unknown
# D: 7% -  3.1MiB  / 41.1MiB  eta unknown
# D: 7% -  3.1MiB  / 41.1MiB  eta unknown
# D: 7% -  3.1MiB  / 41.1MiB  eta unknown
# D: 7% -  3.1MiB  / 41.1MiB  eta unknown
# D: 7% -  3.1MiB  / 41.1MiB  eta unknown
# D: 7% -  3.1MiB  / 41.1MiB  eta unknown
# D: 7% -  3.1MiB  / 41.1MiB  eta unknown
# D: 7% -  3.1MiB  / 41.1MiB  eta unknown
# D: 7% -  3.1MiB  / 41.1MiB  eta unknown
# D: 7% -  3.1MiB  / 41.1MiB  eta unknown
# D: 7% -  3.1MiB  / 41.1MiB  eta unknown
# D: 7% -  3.1MiB  / 41.1MiB  eta unknown
# D: 7% -  3.1MiB  / 41.1MiB  eta unknown
# D: 7% -  3.1MiB  / 41.1MiB  eta unknown
# D: 7% -  3.1MiB  / 41.1MiB  eta unknown
# D: 7% -  3.1MiB  / 41.1MiB  eta unknown
# D: 7% -  3.1MiB  / 41.1MiB  eta unknown
# D: 7% -  3.1MiB  / 41.1MiB  eta unknown
# D: 7% -  3.1MiB  / 41.1MiB  eta unknown
# D: 7% -  3.1MiB  / 41.1MiB  eta unknown
# D: 7% -  3.1MiB  / 41.1MiB  eta unknown
# D: 7% -  3.1MiB  / 41.1MiB  eta unknown
# D: 7% -  3.1MiB  / 41.1MiB  eta unknown
# D: 7% -  3.1MiB  / 41.1MiB  eta unknown
# D: 7% -  3.1MiB  / 41.1MiB  eta unknown
# D: 7% -  3.1MiB  / 41.1MiB  eta unknown
# D: 7% -  3.2MiB  / 41.1MiB  eta unknown
# D: 7% -  3.2MiB  / 41.1MiB  eta unknown
# D: 7% -  3.2MiB  / 41.1MiB  eta unknown
# D: 7% -  3.2MiB  / 41.1MiB  eta unknown
# D: 7% -  3.2MiB  / 41.1MiB  eta unknown
# D: 7% -  3.2MiB  / 41.1MiB  eta unknown
# D: 7% -  3.2MiB  / 41.1MiB  eta unknown
# D: 7% -  3.2MiB  / 41.1MiB  eta unknown
# D: 7% -  3.2MiB  / 41.1MiB  eta unknown
# D: 7% -  3.2MiB  / 41.1MiB  eta unknown
# D: 7% -  3.2MiB  / 41.1MiB  eta unknown
# D: 7% -  3.2MiB  / 41.1MiB  eta unknown
# D: 7% -  3.2MiB  / 41.1MiB  eta unknown
# D: 7% -  3.2MiB  / 41.1MiB  eta unknown
# D: 7% -  3.2MiB  / 41.1MiB  eta unknown
# D: 7% -  3.2MiB  / 41.1MiB  eta unknown
# D: 7% -  3.2MiB  / 41.1MiB  eta unknown
# D: 7% -  3.2MiB  / 41.1MiB  eta unknown
# D: 7% -  3.2MiB  / 41.1MiB  eta unknown
# D: 7% -  3.2MiB  / 41.1MiB  eta unknown
# D: 7% -  3.2MiB  / 41.1MiB  eta unknown
# D: 7% -  3.2MiB  / 41.1MiB  eta unknown
# D: 7% -  3.2MiB  / 41.1MiB  eta unknown
# D: 7% -  3.2MiB  / 41.1MiB  eta unknown
# D: 7% -  3.2MiB  / 41.1MiB  eta unknown
# D: 7% -  3.2MiB  / 41.1MiB  eta unknown
# D: 7% -  3.3MiB  / 41.1MiB  eta unknown
# D: 7% -  3.3MiB  / 41.1MiB  eta unknown
# D: 7% -  3.3MiB  / 41.1MiB  eta unknown
# D: 7% -  3.3MiB  / 41.1MiB  eta unknown
# D: 7% -  3.3MiB  / 41.1MiB  eta unknown
# D: 7% -  3.3MiB  / 41.1MiB  eta unknown
# D: 7% -  3.3MiB  / 41.1MiB  eta unknown
# D: 7% -  3.3MiB  / 41.1MiB  eta unknown
# D: 7% -  3.3MiB  / 41.1MiB  eta unknown
# D: 8% -  3.3MiB  / 41.1MiB  eta unknown
# D: 8% -  3.3MiB  / 41.1MiB  eta unknown
# D: 8% -  3.3MiB  / 41.1MiB  eta unknown
# D: 8% -  3.3MiB  / 41.1MiB  eta unknown
# D: 8% -  3.3MiB  / 41.1MiB  eta unknown
# D: 8% -  3.3MiB  / 41.1MiB  eta unknown
# D: 8% -  3.3MiB  / 41.1MiB  eta unknown
# D: 8% -  3.3MiB  / 41.1MiB  eta unknown
# D: 8% -  3.3MiB  / 41.1MiB  eta unknown
# D: 8% -  3.3MiB  / 41.1MiB  eta unknown
# D: 8% -  3.3MiB  / 41.1MiB  eta unknown
# D: 8% -  3.3MiB  / 41.1MiB  eta unknown
# D: 8% -  3.3MiB  / 41.1MiB  eta unknown
# D: 8% -  3.3MiB  / 41.1MiB  eta unknown
# D: 8% -  3.3MiB  / 41.1MiB  eta unknown
# D: 8% -  3.3MiB  / 41.1MiB  eta unknown
# D: 8% -  3.4MiB  / 41.1MiB  eta unknown
# D: 8% -  3.4MiB  / 41.1MiB  eta unknown
# D: 8% -  3.4MiB  / 41.1MiB  eta unknown
# D: 8% -  3.4MiB  / 41.1MiB  eta unknown
# D: 8% -  3.4MiB  / 41.1MiB  eta unknown
# D: 8% -  3.4MiB  / 41.1MiB  eta unknown
# D: 8% -  3.4MiB  / 41.1MiB  eta unknown
# D: 8% -  3.4MiB  / 41.1MiB  eta unknown
# D: 8% -  3.4MiB  / 41.1MiB  eta unknown
# D: 8% -  3.4MiB  / 41.1MiB  eta unknown
# D: 8% -  3.4MiB  / 41.1MiB  eta unknown
# D: 8% -  3.4MiB  / 41.1MiB  eta unknown
# D: 8% -  3.4MiB  / 41.1MiB  eta unknown
# D: 8% -  3.4MiB  / 41.1MiB  eta unknown
# D: 8% -  3.4MiB  / 41.1MiB  eta unknown
# D: 8% -  3.4MiB  / 41.1MiB  eta unknown
# D: 8% -  3.4MiB  / 41.1MiB  eta unknown
# D: 8% -  3.4MiB  / 41.1MiB  eta unknown
# D: 8% -  3.4MiB  / 41.1MiB  eta unknown
# D: 8% -  3.4MiB  / 41.1MiB  eta unknown
# D: 8% -  3.4MiB  / 41.1MiB  eta unknown
# D: 8% -  3.4MiB  / 41.1MiB  eta unknown
# D: 8% -  3.4MiB  / 41.1MiB  eta unknown
# D: 8% -  3.4MiB  / 41.1MiB  eta unknown
# D: 8% -  3.4MiB  / 41.1MiB  eta unknown
# D: 8% -  3.4MiB  / 41.1MiB  eta unknown
# D: 8% -  3.5MiB  / 41.1MiB  eta unknown
# D: 8% -  3.5MiB  / 41.1MiB  eta unknown
# D: 8% -  3.5MiB  / 41.1MiB  eta unknown
# D: 8% -  3.5MiB  / 41.1MiB  eta unknown
# D: 8% -  3.5MiB  / 41.1MiB  eta unknown
# D: 8% -  3.5MiB  / 41.1MiB  eta unknown
# D: 8% -  3.5MiB  / 41.1MiB  eta unknown
# D: 8% -  3.5MiB  / 41.1MiB  eta unknown
# D: 8% -  3.5MiB  / 41.1MiB  eta unknown
# D: 8% -  3.5MiB  / 41.1MiB  eta unknown
# D: 8% -  3.5MiB  / 41.1MiB  eta unknown
# D: 8% -  3.5MiB  / 41.1MiB  eta unknown
# D: 8% -  3.5MiB  / 41.1MiB  eta unknown
# D: 8% -  3.5MiB  / 41.1MiB  eta unknown
# D: 8% -  3.5MiB  / 41.1MiB  eta unknown
# D: 8% -  3.5MiB  / 41.1MiB  eta unknown
# D: 8% -  3.5MiB  / 41.1MiB  eta unknown
# D: 8% -  3.5MiB  / 41.1MiB  eta unknown
# D: 8% -  3.5MiB  / 41.1MiB  eta unknown
# D: 8% -  3.5MiB  / 41.1MiB  eta unknown
# D: 8% -  3.5MiB  / 41.1MiB  eta unknown
# D: 8% -  3.5MiB  / 41.1MiB  eta unknown
# D: 8% -  3.5MiB  / 41.1MiB  eta unknown
# D: 8% -  3.5MiB  / 41.1MiB  eta unknown
# D: 8% -  3.5MiB  / 41.1MiB  eta unknown
# D: 8% -  3.6MiB  / 41.1MiB  eta unknown
# D: 8% -  3.6MiB  / 41.1MiB  eta unknown
# D: 8% -  3.6MiB  / 41.1MiB  eta unknown
# D: 8% -  3.6MiB  / 41.1MiB  eta unknown
# D: 8% -  3.6MiB  / 41.1MiB  eta unknown
# D: 8% -  3.6MiB  / 41.1MiB  eta unknown
# D: 8% -  3.6MiB  / 41.1MiB  eta unknown
# D: 8% -  3.6MiB  / 41.1MiB  eta unknown
# D: 8% -  3.6MiB  / 41.1MiB  eta unknown
# D: 8% -  3.6MiB  / 41.1MiB  eta unknown
# D: 8% -  3.6MiB  / 41.1MiB  eta unknown
# D: 8% -  3.6MiB  / 41.1MiB  eta unknown
# D: 8% -  3.6MiB  / 41.1MiB  eta unknown
# D: 8% -  3.6MiB  / 41.1MiB  eta unknown
# D: 8% -  3.6MiB  / 41.1MiB  eta unknown
# D: 8% -  3.6MiB  / 41.1MiB  eta unknown
# D: 8% -  3.6MiB  / 41.1MiB  eta unknown
# D: 8% -  3.6MiB  / 41.1MiB  eta unknown
# D: 8% -  3.6MiB  / 41.1MiB  eta unknown
# D: 8% -  3.6MiB  / 41.1MiB  eta unknown
# D: 8% -  3.6MiB  / 41.1MiB  eta unknown
# D: 8% -  3.6MiB  / 41.1MiB  eta unknown
# D: 8% -  3.6MiB  / 41.1MiB  eta unknown
# D: 8% -  3.6MiB  / 41.1MiB  eta unknown
# D: 8% -  3.6MiB  / 41.1MiB  eta unknown
# D: 8% -  3.6MiB  / 41.1MiB  eta unknown
# D: 8% -  3.7MiB  / 41.1MiB  eta unknown
# D: 8% -  3.7MiB  / 41.1MiB  eta unknown
# D: 8% -  3.7MiB  / 41.1MiB  eta unknown
# D: 8% -  3.7MiB  / 41.1MiB  eta unknown
# D: 8% -  3.7MiB  / 41.1MiB  eta unknown
# D: 8% -  3.7MiB  / 41.1MiB  eta unknown
# D: 8% -  3.7MiB  / 41.1MiB  eta unknown
# D: 8% -  3.7MiB  / 41.1MiB  eta unknown
# D: 8% -  3.7MiB  / 41.1MiB  eta unknown
# D: 8% -  3.7MiB  / 41.1MiB  eta unknown
# D: 8% -  3.7MiB  / 41.1MiB  eta unknown
# D: 8% -  3.7MiB  / 41.1MiB  eta unknown
# D: 9% -  3.7MiB  / 41.1MiB  eta unknown
# D: 9% -  3.7MiB  / 41.1MiB  eta unknown
# D: 9% -  3.7MiB  / 41.1MiB  eta unknown
# D: 9% -  3.7MiB  / 41.1MiB  eta unknown
# D: 9% -  3.7MiB  / 41.1MiB  eta unknown
# D: 9% -  3.7MiB  / 41.1MiB  eta unknown
# D: 9% -  3.7MiB  / 41.1MiB  eta unknown
# D: 9% -  3.7MiB  / 41.1MiB  eta unknown
# D: 9% -  3.7MiB  / 41.1MiB  eta unknown
# D: 9% -  3.7MiB  / 41.1MiB  eta unknown
# D: 9% -  3.7MiB  / 41.1MiB  eta unknown
# D: 9% -  3.7MiB  / 41.1MiB  eta unknown
# D: 9% -  3.7MiB  / 41.1MiB  eta unknown
# D: 9% -  3.8MiB  / 41.1MiB  eta unknown
# D: 9% -  3.8MiB  / 41.1MiB  eta unknown
# D: 9% -  3.8MiB  / 41.1MiB  eta unknown
# D: 9% -  3.8MiB  / 41.1MiB  eta unknown
# D: 9% -  3.8MiB  / 41.1MiB  eta unknown
# D: 9% -  3.8MiB  / 41.1MiB  eta unknown
# D: 9% -  3.8MiB  / 41.1MiB  eta unknown
# D: 9% -  3.8MiB  / 41.1MiB  eta unknown
# D: 9% -  3.8MiB  / 41.1MiB  eta unknown
# D: 9% -  3.8MiB  / 41.1MiB  eta unknown
# D: 9% -  3.8MiB  / 41.1MiB  eta unknown
# D: 9% -  3.8MiB  / 41.1MiB  eta unknown
# D: 9% -  3.8MiB  / 41.1MiB  eta unknown
# D: 9% -  3.8MiB  / 41.1MiB  eta unknown
# D: 9% -  3.8MiB  / 41.1MiB  eta unknown
# D: 9% -  3.8MiB  / 41.1MiB  eta unknown
# D: 9% -  3.8MiB  / 41.1MiB  eta unknown
# D: 9% -  3.8MiB  / 41.1MiB  eta unknown
# D: 9% -  3.8MiB  / 41.1MiB  eta unknown
# D: 9% -  3.8MiB  / 41.1MiB  eta unknown
# D: 9% -  3.8MiB  / 41.1MiB  eta unknown
# D: 9% -  3.8MiB  / 41.1MiB  eta unknown
# D: 9% -  3.8MiB  / 41.1MiB  eta unknown
# D: 9% -  3.8MiB  / 41.1MiB  eta unknown
# D: 9% -  3.8MiB  / 41.1MiB  eta unknown
# D: 9% -  3.8MiB  / 41.1MiB  eta unknown
# D: 9% -  3.9MiB  / 41.1MiB  eta unknown
# D: 9% -  3.9MiB  / 41.1MiB  eta unknown
# D: 9% -  3.9MiB  / 41.1MiB  eta unknown
# D: 9% -  3.9MiB  / 41.1MiB  eta unknown
# D: 9% -  3.9MiB  / 41.1MiB  eta unknown
# D: 9% -  3.9MiB  / 41.1MiB  eta unknown
# D: 9% -  3.9MiB  / 41.1MiB  eta unknown
# D: 9% -  3.9MiB  / 41.1MiB  eta unknown
# D: 9% -  3.9MiB  / 41.1MiB  eta unknown
# D: 9% -  3.9MiB  / 41.1MiB  eta unknown
# D: 9% -  3.9MiB  / 41.1MiB  eta unknown
# D: 9% -  3.9MiB  / 41.1MiB  eta unknown
# D: 9% -  3.9MiB  / 41.1MiB  eta unknown
# D: 9% -  3.9MiB  / 41.1MiB  eta unknown
# D: 9% -  3.9MiB  / 41.1MiB  eta unknown
# D: 9% -  3.9MiB  / 41.1MiB  eta unknown
# D: 9% -  3.9MiB  / 41.1MiB  eta unknown
# D: 9% -  3.9MiB  / 41.1MiB  eta unknown
# D: 9% -  3.9MiB  / 41.1MiB  eta unknown
# D: 9% -  3.9MiB  / 41.1MiB  eta unknown
# D: 9% -  3.9MiB  / 41.1MiB  eta unknown
# D: 9% -  3.9MiB  / 41.1MiB  eta unknown
# D: 9% -  3.9MiB  / 41.1MiB  eta unknown
# D: 9% -  3.9MiB  / 41.1MiB  eta unknown
# D: 9% -  3.9MiB  / 41.1MiB  eta unknown
# D: 9% -  3.9MiB  / 41.1MiB  eta unknown
# D: 9% -  4.0MiB  / 41.1MiB  eta unknown
# D: 9% -  4.0MiB  / 41.1MiB  eta unknown
# D: 9% -  4.0MiB  / 41.1MiB  eta unknown
# D: 9% -  4.0MiB  / 41.1MiB  eta unknown
# D: 9% -  4.0MiB  / 41.1MiB  eta unknown
# D: 9% -  4.0MiB  / 41.1MiB  eta unknown
# D: 9% -  4.0MiB  / 41.1MiB  eta unknown
# D: 9% -  4.0MiB  / 41.1MiB  eta unknown
# D: 9% -  4.0MiB  / 41.1MiB  eta unknown
# D: 9% -  4.0MiB  / 41.1MiB  eta unknown
# D: 9% -  4.0MiB  / 41.1MiB  eta unknown
# D: 9% -  4.0MiB  / 41.1MiB  eta unknown
# D: 9% -  4.0MiB  / 41.1MiB  eta unknown
# D: 9% -  4.0MiB  / 41.1MiB  eta unknown
# D: 9% -  4.0MiB  / 41.1MiB  eta unknown
# D: 9% -  4.0MiB  / 41.1MiB  eta unknown
# D: 9% -  4.0MiB  / 41.1MiB  eta unknown
# D: 9% -  4.0MiB  / 41.1MiB  eta unknown
# D: 9% -  4.0MiB  / 41.1MiB  eta unknown
# D: 9% -  4.0MiB  / 41.1MiB  eta unknown
# D: 9% -  4.0MiB  / 41.1MiB  eta unknown
# D: 9% -  4.0MiB  / 41.1MiB  eta unknown
# D: 9% -  4.0MiB  / 41.1MiB  eta unknown
# D: 9% -  4.0MiB  / 41.1MiB  eta unknown
# D: 9% -  4.0MiB  / 41.1MiB  eta unknown
# D: 9% -  4.1MiB  / 41.1MiB  eta unknown
# D: 9% -  4.1MiB  / 41.1MiB  eta unknown
# D: 9% -  4.1MiB  / 41.1MiB  eta unknown
# D: 9% -  4.1MiB  / 41.1MiB  eta unknown
# D: 9% -  4.1MiB  / 41.1MiB  eta unknown
# D: 9% -  4.1MiB  / 41.1MiB  eta unknown
# D: 9% -  4.1MiB  / 41.1MiB  eta unknown
# D: 9% -  4.1MiB  / 41.1MiB  eta unknown
# D: 9% -  4.1MiB  / 41.1MiB  eta unknown
# D: 9% -  4.1MiB  / 41.1MiB  eta unknown
# D: 9% -  4.1MiB  / 41.1MiB  eta unknown
# D: 9% -  4.1MiB  / 41.1MiB  eta unknown
# D: 9% -  4.1MiB  / 41.1MiB  eta unknown
# D: 9% -  4.1MiB  / 41.1MiB  eta unknown
# D: 9% -  4.1MiB  / 41.1MiB  eta unknown
# D: 10% -  4.1MiB  / 41.1MiB  eta unknown
# D: 10% -  4.1MiB  / 41.1MiB  eta unknown
# D: 10% -  4.1MiB  / 41.1MiB  eta unknown
# D: 10% -  4.1MiB  / 41.1MiB  eta unknown
# D: 10% -  4.1MiB  / 41.1MiB  eta unknown
# D: 10% -  4.1MiB  / 41.1MiB  eta unknown
# D: 10% -  4.1MiB  / 41.1MiB  eta unknown
# D: 10% -  4.1MiB  / 41.1MiB  eta unknown
# D: 10% -  4.1MiB  / 41.1MiB  eta unknown
# D: 10% -  4.1MiB  / 41.1MiB  eta unknown
# D: 10% -  4.1MiB  / 41.1MiB  eta unknown
# D: 10% -  4.2MiB  / 41.1MiB  eta unknown
# D: 10% -  4.2MiB  / 41.1MiB  eta unknown
# D: 10% -  4.2MiB  / 41.1MiB  eta unknown
# D: 10% -  4.2MiB  / 41.1MiB  eta unknown
# D: 10% -  4.2MiB  / 41.1MiB  eta unknown
# D: 10% -  4.2MiB  / 41.1MiB  eta unknown
# D: 10% -  4.2MiB  / 41.1MiB  eta unknown
# D: 10% -  4.2MiB  / 41.1MiB  eta unknown
# D: 10% -  4.2MiB  / 41.1MiB  eta unknown
# D: 10% -  4.2MiB  / 41.1MiB  eta unknown
# D: 10% -  4.2MiB  / 41.1MiB  eta unknown
# D: 10% -  4.2MiB  / 41.1MiB  eta unknown
# D: 10% -  4.2MiB  / 41.1MiB  eta unknown
# ...
# D: 96% - 39.6MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.6MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.6MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.6MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.6MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.6MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.6MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.6MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.6MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.6MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.6MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.6MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.6MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.6MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.6MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.6MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.6MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.6MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.6MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.6MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.7MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.7MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.7MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.7MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.7MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.7MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.7MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.7MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.7MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.7MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.7MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.7MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.7MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.7MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.7MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.7MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.7MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.7MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.7MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.7MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.7MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.7MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.7MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.7MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.7MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.8MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.8MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.8MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.8MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.8MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.8MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.8MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.8MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.8MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.8MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.8MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.8MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.8MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.8MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.8MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.8MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.8MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.8MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.8MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.8MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.8MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.8MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.8MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.8MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.8MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.8MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.9MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.9MiB  / 41.1MiB  eta 0:00:01
# D: 96% - 39.9MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 39.9MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 39.9MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 39.9MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 39.9MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 39.9MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 39.9MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 39.9MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 39.9MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 39.9MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 39.9MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 39.9MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 39.9MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 39.9MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 39.9MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 39.9MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 39.9MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 39.9MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 39.9MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 39.9MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 39.9MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 39.9MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 39.9MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 39.9MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.0MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.0MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.0MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.0MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.0MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.0MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.0MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.0MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.0MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.0MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.0MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.0MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.0MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.0MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.0MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.0MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.0MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.0MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.0MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.0MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.0MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.0MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.0MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.0MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.0MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.1MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.1MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.1MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.1MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.1MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.1MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.1MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.1MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.1MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.1MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.1MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.1MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.1MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.1MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.1MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.1MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.1MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.1MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.1MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.1MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.1MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.1MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.1MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.1MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.1MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.1MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.2MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.2MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.2MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.2MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.2MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.2MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.2MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.2MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.2MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.2MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.2MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.2MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.2MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.2MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.2MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.2MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.2MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.2MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.2MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.2MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.2MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.2MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.2MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.2MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.2MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.2MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.3MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.3MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.3MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.3MiB  / 41.1MiB  eta 0:00:01
# D: 97% - 40.3MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.3MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.3MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.3MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.3MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.3MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.3MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.3MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.3MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.3MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.3MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.3MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.3MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.3MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.3MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.3MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.3MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.3MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.3MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.3MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.3MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.4MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.4MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.4MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.4MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.4MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.4MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.4MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.4MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.4MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.4MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.4MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.4MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.4MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.4MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.4MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.4MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.4MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.4MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.4MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.4MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.4MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.4MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.4MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.4MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.4MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.4MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.5MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.5MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.5MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.5MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.5MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.5MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.5MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.5MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.5MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.5MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.5MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.5MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.5MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.5MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.5MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.5MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.5MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.5MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.5MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.5MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.5MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.5MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.5MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.5MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.5MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.6MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.6MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.6MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.6MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.6MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.6MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.6MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.6MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.6MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.6MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.6MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.6MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.6MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.6MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.6MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.6MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.6MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.6MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.6MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.6MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.6MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.6MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.6MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.6MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.6MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.6MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.7MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.7MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.7MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.7MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.7MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.7MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.7MiB  / 41.1MiB  eta 0:00:01
# D: 98% - 40.7MiB  / 41.1MiB  eta 0:00:01
# D: 99% - 40.7MiB  / 41.1MiB  eta 0:00:01
# D: 99% - 40.7MiB  / 41.1MiB  eta 0:00:01
# D: 99% - 40.7MiB  / 41.1MiB  eta 0:00:01
# D: 99% - 40.7MiB  / 41.1MiB  eta 0:00:01
# D: 99% - 40.7MiB  / 41.1MiB  eta 0:00:01
# D: 99% - 40.7MiB  / 41.1MiB  eta 0:00:01
# D: 99% - 40.7MiB  / 41.1MiB  eta 0:00:01
# D: 99% - 40.7MiB  / 41.1MiB  eta 0:00:01
# D: 99% - 40.7MiB  / 41.1MiB  eta 0:00:01
# D: 99% - 40.7MiB  / 41.1MiB  eta 0:00:01
# D: 99% - 40.7MiB  / 41.1MiB  eta 0:00:01
# D: 99% - 40.7MiB  / 41.1MiB  eta 0:00:01
# D: 99% - 40.7MiB  / 41.1MiB  eta 0:00:01
# D: 99% - 40.7MiB  / 41.1MiB  eta 0:00:01
# D: 99% - 40.7MiB  / 41.1MiB  eta 0:00:01
# D: 99% - 40.7MiB  / 41.1MiB  eta 0:00:01
# D: 99% - 40.7MiB  / 41.1MiB  eta 0:00:01
# D: 99% - 40.8MiB  / 41.1MiB  eta 0:00:01
# D: 99% - 40.8MiB  / 41.1MiB  eta 0:00:01
# D: 99% - 40.8MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.8MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.8MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.8MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.8MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.8MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.8MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.8MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.8MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.8MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.8MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.8MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.8MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.8MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.8MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.8MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.8MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.8MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.8MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.8MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.8MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.8MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.8MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.8MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.9MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.9MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.9MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.9MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.9MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.9MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.9MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.9MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.9MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.9MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.9MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.9MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.9MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.9MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.9MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.9MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.9MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.9MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.9MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.9MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.9MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.9MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.9MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.9MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.9MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 40.9MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 41.0MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 41.0MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 41.0MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 41.0MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 41.0MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 41.0MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 41.0MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 41.0MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 41.0MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 41.0MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 41.0MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 41.0MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 41.0MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 41.0MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 41.0MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 41.0MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 41.0MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 41.0MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 41.0MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 41.0MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 41.0MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 41.0MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 41.0MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 41.0MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 41.0MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 41.1MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 41.1MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 41.1MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 41.1MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 41.1MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 41.1MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 41.1MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 41.1MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 41.1MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 41.1MiB  / 41.1MiB  eta 0:00:00
# D: 99% - 41.1MiB  / 41.1MiB  eta 0:00:00
# D: 100% - 41.1MiB  / 41.1MiB  eta 0:00:00

# %%
# step 1.2 Analyze Bulk-RNA-seq 

# Bulk-RNA-seq can handle many more parameters, 
# bulk_data_file, bulk_config_file, gene_format, and species_dataset are required.

gene_format = "ensembl" # gene format in count file for biomart
species_dataset = "human" # species dataset for biomart
exp_prop_rep = 0.5  # proportion of replicates for a gene to be active in a sample
exp_prop_samp = 0.5 # proportion of samples with expression required for gene   
top_percentile = 25 # any replicate with expression in this percentile is expressed, regardless of other sources  
technique = "quantile" # quantile, cpm, or zFPKM
quantile = 90 # only used with quantile

cmd = ' '.join(['python', 'bulk_gen.py', 
      '-f', '"{}"'.format(bulk_data_file),   # bulk rna-seq data sheet (required)
      '-c', '"{}"'.format(bulk_config_file), # config file for bulk RNA-seq (required)
      '-g', '"{}"'.format(gene_format),      # gene format in count file for biomart (required)
      '-d', '"{}"'.format(species_dataset),  # species dataset for biomart (required)
      '-r', '"{}"'.format(exp_prop_rep),     # proportion of replicates for a gene to be active in a sample
      '-s', '"{}"'.format(exp_prop_samp),    # proportion of samples with expression required for gene       
      '-p', '"{}"'.format(top_percentile),   # top percentile 
      '-t', '"{}"'.format(technique),        # technique for filtering and normalization    
      '-q', '"{}"'.format(quantile)])         # cutoff TPM quantile for quantile techique
                
# !{cmd}
# Out:
# Data file is "BulkRNAseqDataMatrix.csv"
# Supplementary Data file is "bulk_data_inputs.csv"
# G:/GitHub/MADRID/docker/pipelines/data\Bulk_Naive.csv
# Test data saved to G:/GitHub/MADRID/docker/pipelines/data\Bulk_Naive.csv
# C:\Users\babes\Anaconda3\lib\site-packages\rpy2\robjects\pandas2ri.py:17: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import Index as PandasIndex

# %%
# Step 1.3 Analyze proteomics
cmd = ' '.join(['python', 'proteomics_gen.py', 
      '-d', '"{}"'.format(proteomics_data_file), 
      '-s', '"{}"'.format(proteomics_config_file),
      '-e', '"{}"'.format(expression_proportion),
      '-p', '"{}"'.format(top_percentile)])
# !{cmd}
# Out:
# Data file is "ProteomicsDataMatrix.xlsx"
# Supplementary Data file is "proteomics_data_inputs.xlsx"
#                                 Naïve
# 0     CopyNumber_T4.naive_01_activated
# 1     CopyNumber_T4.naive_02_activated
# 2     CopyNumber_T4.naive_03_activated
# 3     CopyNumber_T4.naive_04_activated
# 4  CopyNumber_T4.naive_01_steady-state
# 5  CopyNumber_T4.naive_02_steady-state
# 6  CopyNumber_T4.naive_03_steady-state
# 7  CopyNumber_T4.naive_04_steady-state
# Test Data Saved to G:/GitHub/MADRID/docker/pipelines/data\Proteomics_Naive.csv
# C:\Users\babes\Anaconda3\lib\site-packages\rpy2\robjects\pandas2ri.py:17: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import Index as PandasIndex

# %%
# Step 1.4 Merge the gene lists of transcriptomics and proteomics, create a list of active gene IDs
cmd = ' '.join(['python', 'merge_xomics.py', 
      #'-t', '"{}"'.format(transcriptomics_config_file),
      '-b', '"{}"'.format(bulk_config_file),
      '-p', '"{}"'.format(proteomics_config_file),])
# !{cmd}
# Out:
# Transcriptomics file is "None"
# Proteomics file is "proteomics_data_inputs.xlsx"
# Bulk RNA-seq file is "bulk_data_inputs.csv"
#                                 Naïve
# 0     CopyNumber_T4.naive_01_activated
# 1     CopyNumber_T4.naive_02_activated
# 2     CopyNumber_T4.naive_03_activated
# 3     CopyNumber_T4.naive_04_activated
# 4  CopyNumber_T4.naive_01_steady-state
# 5  CopyNumber_T4.naive_02_steady-state
# 6  CopyNumber_T4.naive_03_steady-state
# 7  CopyNumber_T4.naive_04_steady-state
# proteomics exists
# Naïve
# Test Data Load From G:/GitHub/MADRID/docker/pipelines/data\Proteomics_Naive.csv
# {'Naive':                 CopyNumber_T4.naive_01_activated  ...  top
# ENTREZ_GENE_ID                                    ...
# 1                                          42776  ...    0
# 2                                         341085  ...    0
# 144568                                         0  ...    0
# 8086                                      109983  ...    0
# 65985                                      13945  ...    0
# ...                                          ...  ...  ...
# 440590                                     11600  ...    0
# 79699                                      10117  ...    0
# 7791                                      784378  ...    1
# 23140                                      11113  ...    0
# 26009                                          0  ...    0
#
# [8768 rows x 11 columns]}
#       SampleName InsertSize
# 0       FILENAME      Naive
# 1       GROUP_S1   GROUP_S1
# 2   Naive_B_S1R1          0
# 3   Naive_B_S1R2          0
# 4   Naive_B_S1R3          0
# 5   Naive_B_S1R4          0
# 6       GROUP_S2   GROUP_S1
# 7   Naive_B_S2R1          0
# 8   Naive_B_S2R2          0
# 9   Naive_B_S2R3          0
# 10  Naive_B_S2R4          0
# 11      GROUP_S3   GROUP_S1
# 12  Naive_B_S3R1          0
# 13  Naive_B_S3R2          0
# 14  Naive_B_S3R3          0
# 15  Naive_B_S3R4          0
# 16  Naive_B_S3R5          0
# 17  Naive_B_S3R6          0
#   SampleName InsertSize
# 0   FILENAME      Naive
# 0    Naive
# Name: InsertSize, dtype: object
# bulk exists
# Naive
# expressed    int64
# top          int64
# dtype: object
# Test Data Load From G:/GitHub/MADRID/docker/pipelines/data\Bulk_Naive.csv
# {'Naive':                 expressed  top
# ENTREZ_GENE_ID
# 7105                    0    0
# 64102                   0    0
# 8813                    0    0
# 57147                   0    0
# 55732                   0    0
# ...                   ...  ...
# 105370174               0    0
# 100533105               0    0
# 109617009               0    0
# C:\Users\babes\Anaconda3\lib\site-packages\rpy2\robjects\pandas2ri.py:17: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import Index as PandasIndex
# 2831                    0    0
# 1038                    0    0
#
# [25639 rows x 2 columns]}
# dict_keys(['Naive'])
# dict_keys(['Naive'])
# {'Naive'}
# set()
# keys1 generated
# Naive
#                 prote_exp  prote_top
# ENTREZ_GENE_ID
# 1                       1          0
# 2                       1          0
# 144568                  1          0
# 8086                    1          0
# 65985                   1          0
# ...                   ...        ...
# 440590                  1          0
# 79699                   1          0
# 7791                    1          1
# 23140                   1          0
# 26009                   0          0
#
# [8768 rows x 2 columns]
#                 bulk_exp  bulk_top
# ENTREZ_GENE_ID
# 7105                   0         0
# 64102                  0         0
# 8813                   0         0
# 57147                  0         0
# 55732                  0         0
# ...                  ...       ...
# 105370174              0         0
# 100533105              0         0
# 109617009              0         0
# 2831                   0         0
# 1038                   0         0
#
# [25639 rows x 2 columns]
#                 prote_exp  prote_top  bulk_exp  bulk_top
# ENTREZ_GENE_ID
# 1                     NaN        NaN       0.0       0.0
# 2                     NaN        NaN       0.0       0.0
# 3                     NaN        NaN       0.0       0.0
# 9                     NaN        NaN       0.0       0.0
# 10                    NaN        NaN       0.0       0.0
# ...                   ...        ...       ...       ...
# 999                   0.0        0.0       NaN       NaN
# 9990                  1.0        0.0       NaN       NaN
# 9991                  1.0        0.0       NaN       NaN
# 9994                  1.0        0.0       NaN       NaN
# 9997                  1.0        0.0       NaN       NaN
#
# [34407 rows x 4 columns]
# ENTREZ_GENE_ID     object
# prote_exp         float64
# prote_top         float64
# bulk_exp          float64
# bulk_top          float64
# dtype: object
# 17 single ENTREZ_GENE_IDs to merge
# id_list: 20, set: 20
# entrez_single_id_list: 34399, set: 25710
# entrez_id_list: 8, set: 8
# dups: 0, set: 0
# 8 id merged
#                 prote_exp  prote_top  bulk_exp  bulk_top
# ENTREZ_GENE_ID
# 1                     1.0        0.0       0.0       0.0
# 10                    NaN        NaN       0.0       0.0
# 100                   1.0        1.0       0.0       0.0
# 1000                  0.0        0.0       0.0       0.0
# 10000                 1.0        0.0       0.0       0.0
# ...                   ...        ...       ...       ...
# 9991                  1.0        0.0       0.0       0.0
# 9992                  NaN        NaN       0.0       0.0
# 9993                  NaN        NaN       0.0       0.0
# 9994                  1.0        0.0       0.0       0.0
# 9997                  1.0        0.0       0.0       0.0
#
# [25701 rows x 4 columns]
# (25693, 2)
# (8, 2)
# (20, 2)
# (25713, 2)
# Naive: save to G:/GitHub/MADRID/docker/pipelines/data\GeneExpression_Naive_Merged.csv
#
# {'Naive': 'G:/GitHub/MADRID/docker/pipelines/data\\GeneExpression_Naive_Merged.csv'}

# %% [markdown]
# ## Step 2: Create tissue-specific or cell-type-specific Models

# %%
# Load the output of step 1, which is a dictionary that specifies the merged list of active Gene IDs for each tissue

step1_results_file = os.path.join(configs.rootdir, 'data', 'step1_results_files.json')
with open(step1_results_file) as json_file:
    tissue_gene_exp = json.load(json_file)
print(tissue_gene_exp)
# Out:
# {'Naive': 'G:/GitHub/MADRID/docker/pipelines/data\\GeneExpression_Naive_Merged.csv'}

# %% [markdown]
# *** Specify input files for step 2 here ***

# %%
# (input) filename of General Model, Recon3D_Teff_ver2
GeneralModelFile = 'GeneralModel.mat'

# (input) filename of Tissue Gene Expression
# genefile = 'merged_Th1.csv'

# (output) filename of Tissue Specific Model
# tissuefile = 'Th1_SpecificModel.mat'

# %%
# create tissue specific model, the names of output files are stored in dictionary tissue_spec_model
tissue_spec_model = {}

for key,value in tissue_gene_exp.items():
    tissuefile = '{}_SpecificModel.mat'.format(key)
    tissue_spec_model[key] = tissuefile
    tissue_gene_file = re.split('/|\\\\', value)[-1]
    tissue_gene_folder = os.path.join(configs.rootdir, 'data', key)
    os.makedirs(tissue_gene_folder, exist_ok=True)
    cmd = ' '.join(['python', 'create_tissue_specific_model.py', 
                      '-m', '"{}"'.format(GeneralModelFile), 
                      '-g', '"{}"'.format(tissue_gene_file),
                      '-o', '"{}"'.format(tissuefile)])
    # !{cmd}

print(tissue_spec_model)
# Out:
# General Model file is "GeneralModel.mat"
# Gene Expression file is "GeneExpression_Naive_Merged.csv"
# Output file is "Naive_SpecificModel.mat"
# (25713, 2)
# (0, 2)
# (0, 2)
# (25713, 2)
# Map gene expression to reactions, 0 errors.
# 1's: 5858
# 2's: 0
# model
# Genes: 666
# Metabolites: 5174
# Reactions: 5858
# 1.0*biomass_reaction_Mphage - 1.0*biomass_reaction_Mphage_reverse_6cff5
# <Solution 0.000 at 0x19dd13d0908>
# {'Naive': 'Naive_SpecificModel.mat'}
# C:\Users\babes\Anaconda3\lib\site-packages\cobamp\gpr\core.py:116: UserWarning: Will not normalize rules with more than 20 average tokens per gene
#   'Will not normalize rules with more than ' + str(token_to_gene_ratio) + ' average tokens per gene')
# create_tissue_specific_model.py:186: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   expVector = np.array(list(expressionRxns.values()),dtype=np.float)

# %% [markdown]
# ## Step 3: Identifying disease related genes by analyzing transcriptomics data of patients
# Differential Expression Analysis
#
# Only 1 disease to be analyzed, output files in data folder

# %% [markdown]
# *** Specify input files for step 3 here ***

# %%
#input filename transcriptomics data of disease
disease_gene_file = 'disease_transcriptomics_data_inputs.xlsx'

# %%
# Differential gene expression analysis
cmd = ' '.join(['python3', 'disease_analysis.py', 
              '-i', '"{}"'.format(disease_gene_file)])
# !{cmd}

# %%
# load the results of step 3 to dictionary 'disease_files'
step3_results_file = os.path.join(configs.datadir, 'step2_results_files.json')
with open(step3_results_file) as json_file:
    disease_files = json.load(json_file)
print(disease_files)

# %% [markdown]
# ## Step 4: Identification of drug targets and repurposable drugs
# This step maps drug targets in metabolic models,prforms knock out simulation, and compare simulation results with disease genes and identifies drug targets and repurposable drugs
#
# *** Specify input files for step 4 here ***
#
# 1. Instruction: A processed Drug-Target file is included in the `/root/pipelines/data/`. (Optional step) For the updated versions the users can download `Repurposing_Hub_export.txt` from [Drug Repurposing Hub](https://clue.io/repurposing-app). From the downloaded file first remove all the activators, agonists, and withdrawn drugs and then upload to to `/root/pipelines/data/`.

# %% [markdown]
# 2. To use automatically created tissue specific models. Note: It is recommended to use refined and validated models for further analysis. User can define cutomized models in next sub-step.

# %%
# tissue specific models
tissue_spec_model

# %%
Disease_Down = disease_files['DN_Reg']
Disease_Up = disease_files['UP_Reg']
drug_raw_file = 'Repurposing_Hub_export.txt'

# %% [markdown]
# 3. To use customized model, please specify `tissue_spec_model` manually, e.g. uncomment tissue_spec_model in the following cell.

# %%
# Manually specify Up and Down Regulated Genes for Disease. (Please upload manually created files `/pipelines/data/`. Use filenames as given belwo or change them accordingly.)
# Disease_Down = 'Disease_DOWN.txt'
# Disease_Up = 'Disease_UP.txt'
# drug_raw_file = 'Repurposing_Hub_export.txt'

# Manually specify tissue specific models fine-tuned by user. Change names of the files accordingly. Users can use single or multiple models here. Using multiple models, simulation time will increase.
# tissue_spec_model = {'Th1':'Th1Model.mat',
#                      'Th2':'Th2Model.mat',
#                      'Th17':'Th17Model.mat',
#                      'Naive':'NaiveModel.mat'}

# Manually specify tissue specific model created by matlab cobratoolbox. For example run, we have provided four models of CD4+ T cells (niave, Th1, Th2, and Th17) please uncomment all or any specific model
# tissue_spec_model = {'Th1':'Th1_SpecificModel_matlab.mat',
#                      'Th2':'Th2_SpecificModel_matlab.mat',
#                      'Th17':'Th17_SpecificModel_matlab.mat',
#                      'Naive':'Naive_SpecificModel_matlab.mat'}

# %%
# Knock out simulation for the analyzed tissues
for key,value in tissue_spec_model.items():
    tissueSpecificModelfile = value
    tissue_gene_folder = os.path.join(configs.datadir, key)
    os.makedirs(tissue_gene_folder, exist_ok=True)
    inhibitors_file = '{}_inhibitors_Entrez.txt'.format(key)
    cmd = ' '.join(['python3' , 'knock_out_simulation.py',
                  '-t', tissueSpecificModelfile,
                  '-i', inhibitors_file,
                  '-u', Disease_Up,
                  '-d', Disease_Down,
                  '-f', key,
                  '-r', drug_raw_file])
    # !{cmd}
    
    # copy generated output to output folder
    cmd = ' '.join(['cp', '-a', os.path.join(configs.datadir, key), configs.outputdir])
    # !{cmd}
    #break
