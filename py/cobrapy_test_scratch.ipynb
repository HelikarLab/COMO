# %%
import os
import pandas as pd
import numpy as np
from project import configs

# %%
from knock_out_simulation import *

# %%
from transcriptomic_gen import *
from proteomics_gen import *

# %%
print(configs.rootdir)
print(configs.datadir)
# Out:
# /Users/zhzhao/Dropbox/Helikar/pipelines
# /Users/zhzhao/Dropbox/Helikar/pipelines/data

# %% [markdown]
# ```m
# [grRatio,grRateKO,grRateWT,hasEffect,delRxns] = singleGeneDeletion(model,'MOMA',DT_model)
# hasEffect_DT=find(hasEffect==1)
# hasEffect_DTgenes=DT_model(hasEffect_DT)
# [grRatio,grRateKO,grRateWT,hasEffect,delRxns,fluxSolution] = singleGeneDeletion(model,'MOMA',hasEffect_DTgenes)
# ```

# %%
model, geneInd2genes, HasEffects_Gene, fluxSolutionRatios, fluxSolutionDiffs = knock_out_simulation(datadir=configs.datadir,
                                  model_file='Th1_Cell_SpecificModel4manuscript.mat',
                                  inhibitors='Th1_inhibitors_Entrez.txt')
# Out:
# 1133
# 1133
# 247

# %%
fluxSolutionDiffs
# Out:
#                          5244          6392          5293          5295  \
# ASNS1                     0.0  0.000000e+00  0.000000e+00  0.000000e+00
# ASPNATm                   0.0  0.000000e+00  0.000000e+00  0.000000e+00
# ASPTA                     0.0 -4.869706e-01 -4.869706e-01 -4.869706e-01
# ASPTAm                    0.0  0.000000e+00  0.000000e+00  0.000000e+00
# ACGAMK                    0.0 -6.630034e-02 -6.630034e-02 -6.630034e-02
# ...                       ...           ...           ...           ...
# RE2948C                   0.0  0.000000e+00  0.000000e+00  0.000000e+00
# AIRCr_PRASCS              0.0 -4.707358e+01 -4.707358e+01 -4.707358e+01
# biomass_reaction_Mphage   0.0 -3.064216e-14 -3.064216e-14 -3.064216e-14
# RTOT_3                    0.0 -8.287542e-02 -8.287542e-02 -8.287542e-02
# ARTFR13                   0.0 -9.471477e-02 -9.471477e-02 -9.471477e-02
#
#                                  7173          5136           216  \
# ASNS1                    0.000000e+00  0.000000e+00  0.000000e+00
# ASPNATm                  0.000000e+00  0.000000e+00  0.000000e+00
# ASPTA                   -4.869706e-01 -4.869706e-01 -4.869706e-01
# ASPTAm                   0.000000e+00  0.000000e+00  0.000000e+00
# ACGAMK                  -6.630034e-02 -6.630034e-02 -6.630034e-02
# ...                               ...           ...           ...
# RE2948C                  0.000000e+00  0.000000e+00  0.000000e+00
# AIRCr_PRASCS            -4.707358e+01 -4.707358e+01 -4.707358e+01
# biomass_reaction_Mphage -3.064216e-14 -3.064216e-14 -3.064216e-14
# RTOT_3                  -8.287542e-02 -8.287542e-02 -8.287542e-02
# ARTFR13                 -9.471477e-02 -9.471477e-02 -9.471477e-02
#
#                                 10135           570          8694  ...  \
# ASNS1                    0.000000e+00  0.000000e+00  0.000000e+00  ...
# ASPNATm                  0.000000e+00  0.000000e+00  0.000000e+00  ...
# ASPTA                   -4.869706e-01 -4.869706e-01 -4.869706e-01  ...
# ASPTAm                   0.000000e+00  0.000000e+00  0.000000e+00  ...
# ACGAMK                  -6.630034e-02 -6.630034e-02 -6.630034e-02  ...
# ...                               ...           ...           ...  ...
# RE2948C                  0.000000e+00  0.000000e+00  0.000000e+00  ...
# AIRCr_PRASCS            -4.707358e+01 -4.707358e+01 -4.707358e+01  ...
# biomass_reaction_Mphage -3.064216e-14 -3.064216e-14 -3.064216e-14  ...
# RTOT_3                  -8.287542e-02 -8.287542e-02 -8.287542e-02  ...
# ARTFR13                 -9.471477e-02 -9.471477e-02 -9.471477e-02  ...
#
#                               5033       2222       4758      11254  \
# ASNS1                     0.000000   0.000000   0.000000   0.000000
# ASPNATm                   0.000000   0.000000   0.000000   0.000000
# ASPTA                     1.332995   1.332995   1.332995   1.332995
# ASPTAm                    0.000000   0.000000   0.000000   0.000000
# ACGAMK                   -0.068190  -0.068190  -0.068190  -0.068190
# ...                            ...        ...        ...        ...
# RE2948C                   0.000000   0.000000   0.000000   0.000000
# AIRCr_PRASCS            -47.847671 -47.847671 -47.847671 -47.847671
# biomass_reaction_Mphage  -1.722327  -1.722327  -1.722327  -1.722327
# RTOT_3                   -0.085237  -0.085237  -0.085237  -0.085237
# ARTFR13                  -0.097414  -0.097414  -0.097414  -0.097414
#
#                             115584       9536       2194       9194  \
# ASNS1                     0.000000   0.000000   0.000000   0.000000
# ASPNATm                   0.000000   0.000000   0.000000   0.000000
# ASPTA                     1.332995   1.332995   1.332995   1.332995
# ASPTAm                    0.000000   0.000000   0.000000   0.000000
# ACGAMK                   -0.068190  -0.068190  -0.068190  -0.068190
# ...                            ...        ...        ...        ...
# RE2948C                   0.000000   0.000000   0.000000   0.000000
# AIRCr_PRASCS            -47.847671 -47.847671 -47.847671 -47.847671
# biomass_reaction_Mphage  -1.722327  -1.722327  -1.722327  -1.722327
# RTOT_3                   -0.085237  -0.085237  -0.085237  -0.085237
# ARTFR13                  -0.097414  -0.097414  -0.097414  -0.097414
#
#                               8974      27165
# ASNS1                     0.000000   0.000000
# ASPNATm                   0.000000   0.000000
# ASPTA                     1.332995   1.332995
# ASPTAm                    0.000000   0.000000
# ACGAMK                   -0.068190  -0.068190
# ...                            ...        ...
# RE2948C                   0.000000   0.000000
# AIRCr_PRASCS            -47.847671 -47.847671
# biomass_reaction_Mphage  -1.722327  -1.722327
# RTOT_3                   -0.085237  -0.085237
# ARTFR13                  -0.097414  -0.097414
#
# [3956 rows x 247 columns]

# %%
print(fluxSolutionRatios.shape)
fluxSolutionRatios
# Out:
# (3956, 247)
#                          5244      6392      5293      5295      7173  \
# ASNS1                     NaN       NaN       NaN       NaN       NaN
# ASPNATm                   NaN       NaN       NaN       NaN       NaN
# ASPTA                     1.0  1.365321  1.365321  1.365321  1.365321
# ASPTAm                    NaN       NaN       NaN       NaN       NaN
# ACGAMK                    1.0  0.027707  0.027707  0.027707  0.027707
# ...                       ...       ...       ...       ...       ...
# RE2948C                   NaN       NaN       NaN       NaN       NaN
# AIRCr_PRASCS              1.0  5.876915  5.876915  5.876915  5.876915
# biomass_reaction_Mphage   1.0  1.000000  1.000000  1.000000  1.000000
# RTOT_3                    1.0  0.027707  0.027707  0.027707  0.027707
# ARTFR13                   1.0  0.027707  0.027707  0.027707  0.027707
#
#                              5136       216     10135       570      8694  \
# ASNS1                         NaN       NaN       NaN       NaN       NaN
# ASPNATm                       NaN       NaN       NaN       NaN       NaN
# ASPTA                    1.365321  1.365321  1.365321  1.365321  1.365321
# ASPTAm                        NaN       NaN       NaN       NaN       NaN
# ACGAMK                   0.027707  0.027707  0.027707  0.027707  0.027707
# ...                           ...       ...       ...       ...       ...
# RE2948C                       NaN       NaN       NaN       NaN       NaN
# AIRCr_PRASCS             5.876915  5.876915  5.876915  5.876915  5.876915
# biomass_reaction_Mphage  1.000000  1.000000  1.000000  1.000000  1.000000
# RTOT_3                   0.027707  0.027707  0.027707  0.027707  0.027707
# ARTFR13                  0.027707  0.027707  0.027707  0.027707  0.027707
#
#                          ...      5033      2222      4758     11254  \
# ASNS1                    ...       NaN       NaN       NaN       NaN
# ASPNATm                  ...       NaN       NaN       NaN       NaN
# ASPTA                    ... -0.000000 -0.000000 -0.000000 -0.000000
# ASPTAm                   ...       NaN       NaN       NaN       NaN
# ACGAMK                   ...  0.000000  0.000000  0.000000  0.000000
# ...                      ...       ...       ...       ...       ...
# RE2948C                  ...       NaN       NaN       NaN       NaN
# AIRCr_PRASCS             ...  5.957112  5.957112  5.957112  5.957112
# biomass_reaction_Mphage  ...  0.000000  0.000000  0.000000  0.000000
# RTOT_3                   ...  0.000000  0.000000  0.000000  0.000000
# ARTFR13                  ...  0.000000  0.000000  0.000000  0.000000
#
#                            115584      9536      2194      9194      8974  \
# ASNS1                         NaN       NaN       NaN       NaN       NaN
# ASPNATm                       NaN       NaN       NaN       NaN       NaN
# ASPTA                   -0.000000 -0.000000 -0.000000 -0.000000 -0.000000
# ASPTAm                        NaN       NaN       NaN       NaN       NaN
# ACGAMK                   0.000000  0.000000  0.000000  0.000000  0.000000
# ...                           ...       ...       ...       ...       ...
# RE2948C                       NaN       NaN       NaN       NaN       NaN
# AIRCr_PRASCS             5.957112  5.957112  5.957112  5.957112  5.957112
# biomass_reaction_Mphage  0.000000  0.000000  0.000000  0.000000  0.000000
# RTOT_3                   0.000000  0.000000  0.000000  0.000000  0.000000
# ARTFR13                  0.000000  0.000000  0.000000  0.000000  0.000000
#
#                             27165
# ASNS1                         NaN
# ASPNATm                       NaN
# ASPTA                   -0.000000
# ASPTAm                        NaN
# ACGAMK                   0.000000
# ...                           ...
# RE2948C                       NaN
# AIRCr_PRASCS             5.957112
# biomass_reaction_Mphage  0.000000
# RTOT_3                   0.000000
# ARTFR13                  0.000000
#
# [3956 rows x 247 columns]

# %%
Gene_Pairs_down = create_gene_pairs(configs.datadir,
                                   model,
                                   geneInd2genes,
                                   fluxSolutionRatios,
                                   HasEffects_Gene,
                                   RA_Down='RA_DOWN.txt')
# Gene_Pairs_down.to_csv(os.path.join(configs.datadir,'Gene_Pairs_Inhi_Fratio_DOWN.txt'),index=False)
Gene_Pairs_down
# Out:
#          reaction Gene IDs  rxn_fluxRatio   Gene
# 0     NADH2_u10mi     4719       5.297182   6392
# 1           LPASE     1178       0.027707   6392
# 2          PMEVKc    10654      19.283360   6392
# 3           PROt4    81539       1.000000   6392
# 4           METt4    81539       1.000000   6392
# ...           ...      ...            ...    ...
# 2389     ECOAH12m     3030       0.000000  27165
# 2390         DHFR     1719      -0.000000  27165
# 2391        r0226     1719       0.000000  27165
# 2392        SERPT     9517       0.000000  27165
# 2393       SUCD1m     6391       0.000000  27165
#
# [2394 rows x 4 columns]

# %%
Gene_Pairs_up = create_gene_pairs(configs.datadir,
                                   model,
                                   geneInd2genes,
                                   fluxSolutionRatios,
                                   HasEffects_Gene,
                                   RA_Down='RA_UP.txt')
# Gene_Pairs_up.to_csv(os.path.join(configs.datadir,'Gene_Pairs_Inhi_Fratio_UP.txt'),index=False)
Gene_Pairs_up
# Out:
#         reaction Gene IDs  rxn_fluxRatio   Gene
# 0         LSTO1r     6309       1.000000   6392
# 1    NADH2_u10mi     4710       5.297182   6392
# 2         NDP7er     9583            inf   6392
# 3    NADH2_u10mi     4714       5.297182   6392
# 4         LSTO1r     6309       1.000000    570
# ..           ...      ...            ...    ...
# 396  NADH2_u10mi     4710       0.000000   9194
# 397  NADH2_u10mi     4714       0.000000   9194
# 398       LSTO1r     6309       0.000000  27165
# 399  NADH2_u10mi     4710       0.000000  27165
# 400  NADH2_u10mi     4714       0.000000  27165
#
# [401 rows x 4 columns]

# %%
print(len(HasEffects_Gene))
print(len(geneInd2genes))
print(Gene_Pairs_up.Gene.unique().size)
print(Gene_Pairs_down.Gene.unique().size)
# Out:
# 118
# 1133
# 118
# 118

# %%
p_model_genes = Gene_Pairs_up.Gene.unique()
d_score = pd.DataFrame([],columns=['score'])
for p_gene in p_model_genes:
    data_p = Gene_Pairs_up.loc[Gene_Pairs_up['Gene']==p_gene].copy()
    # print(data_p)
    total_aff = data_p['Gene IDs'].unique().size
    # print(total_aff)
    n_aff_down=data_p.loc[data_p['rxn_fluxRatio']<-1e-8, 'Gene IDs'].unique().size
    # print(n_aff_down)
    n_aff_up=data_p.loc[data_p['rxn_fluxRatio'] >1e-8, 'Gene IDs'].unique().size
    # print(n_aff_up)
    d_s=((n_aff_down - n_aff_up)/total_aff)
    # print(d_s)
    d_score.at[p_gene,'score'] = d_s

d_score.index.name='Gene'
# d_score.to_csv(os.path.join(configs.datadir,'d_score_UP.csv'))
d_score
# Out:
#           score
# Gene
# 132   -0.111111
# 3099  -0.111111
# 5831  -0.111111
# 4953  -0.111111
# 51727 -0.111111
# ...         ...
# 5321   0.222222
# 3418   0.222222
# 7298   0.222222
# 586    0.222222
# 4535   0.222222
#
# [133 rows x 1 columns]

# %%
d_score_down = score_gene_pairs(Gene_Pairs_down, 'd_score_DOWN.csv')
d_score_up = score_gene_pairs(Gene_Pairs_up, 'd_score_UP.csv')
# print(d_score_down)
d_score_up
# Out:
#        score
# Gene
# 6392   -0.75
# 570    -0.75
# 8694   -0.75
# 2182   -0.75
# 5836   -0.75
# ...      ...
# 11254      1
# 115584     1
# 2194       1
# 9194       1
# 27165      1
#
# [118 rows x 1 columns]

# %%
d_score_up-d_score_down
# Out:
#        score
# Gene
# 6392   -0.65
# 570    -0.65
# 8694   -0.65
# 2182   -0.65
# 5836   -0.65
# ...      ...
# 11254      0
# 115584     0
# 2194       0
# 9194       0
# 27165      0
#
# [118 rows x 1 columns]

# %% [markdown]
# create network of genes based on the change
#
# ```m
# gene_mat_out=[];
# for i = 1:length(hasEffect_DTgenes)
#     FR_i=DAG_rxn_fluxRatio(:,i)
#     naN_ind= find(isnan(DAG_rxn_fluxRatio(:,i)))
#     FR_i([naN_ind])=[];
#     Gene_i=combined_output{1}
#     Gene_i([naN_ind])=[];
#     Rind_i=combined_output{2}
#     Rind_i([naN_ind])=[];
#
#     P_gene=repelem(hasEffect_DTgenes(i),length(Gene_i))
#     P_gene=P_gene'
#     pegene_mat=[P_gene Gene_i num2cell(FR_i)]
#     gene_mat_out=[gene_mat_out; pegene_mat]
# end
#
# % Change_file_name here
# T = cell2table(gene_mat_out);
# writetable(T,'Gene_Pairs_Inhi_Fratio_DOWN.txt')
# ```

# %%
temp  =pd.read_csv(os.path.join(configs.rootdir,'code','Gene_Pairs_Inhi_Fratio_UP.txt'))
temp.rename(columns={'gene_mat_out1':'Gene','gene_mat_out2':'Gene IDs','gene_mat_out3':'rxn_fluxRatio'},inplace=True)
temp
# Out:
#       Gene  Gene IDs  rxn_fluxRatio
# 0      100      6309       1.000000
# 1      100      7360      -0.000001
# 2      100     56261            inf
# 3      100      4710       0.570537
# 4      100      4714       0.570537
# ...    ...       ...            ...
# 1242   952      6515       0.007098
# 1243   952      6515            inf
# 1244   952    144195       0.007098
# 1245   952      9990       0.002550
# 1246   952      9990       0.000508
#
# [1247 rows x 3 columns]

# %%
d_score_temp =score_gene_pairs(temp, 'd_score_temp.csv')
d_score_temp
# Out:
#             score
# Gene
# 100         0.625
# 10135         0.5
# 10682   0.0769231
# 114971      0.625
# 128         0.625
# ...           ...
# 847      0.181818
# 8833        0.625
# 9194        0.625
# 9453      -0.1875
# 952           0.5
#
# [99 rows x 1 columns]

# %%
load_haseffect = set(temp.Gene.tolist())
load_haseffect
calc_haseffect = set(HasEffects_Gene)
load_haseffect.intersection(calc_haseffect)
# Out:
# set()

# %%
bm_d_score_Up = pd.read_csv(os.path.join(configs.rootdir,'code','bm_d_score_UP.txt'))
bm_d_score_Down = pd.read_csv(os.path.join(configs.rootdir,'code','bm_d_score_DOWN.txt'))

# %%
bm_d_score_Up
# Out:
#                               x
# 0                   1 "100 0.5"
# 1               2 "10135 0.375"
# 2                   3 "10682 0"
# 3                4 "114971 0.5"
# 4                   5 "128 0.5"
# ..                          ...
# 94  95 "847 0.0909090909090909"
# 95                96 "8833 0.5"
# 96                97 "9194 0.5"
# 97              98 "9453 -0.25"
# 98               99 "952 0.375"
#
# [99 rows x 1 columns]

# %%
ld_d_score_Up = pd.read_csv(os.path.join(configs.datadir,'d_score_UP.csv'),index_col='Gene')
ld_d_score_Down = pd.read_csv(os.path.join(configs.datadir,'d_score_DOWN.csv'),index_col='Gene')

# %%
ld_d_score_Up - ld_d_score_Down
# Out:
#           score
# Gene
# 2222  -0.233333
# 5321  -0.233333
# 2182  -0.233333
# 587   -0.533333
# 23539 -0.533333
# ...         ...
# 3612   0.000000
# 10682  0.000000
# 9123   0.000000
# 513    0.000000
# 6524   0.000000
#
# [111 rows x 1 columns]
