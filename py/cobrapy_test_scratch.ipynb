# %%
import os
import pandas as pd
import numpy as np
from project import configs
import cobra

# %%
from knock_out_simulation import *

# %%
from cobra.flux_analysis import moma

# %%
print(configs.rootdir)
print(configs.datadir)
# Out:
# /Users/zhzhao/Dropbox/Helikar/pipelines
# /Users/zhzhao/Dropbox/Helikar/pipelines/data

# %% [markdown]
# ```m
# [grRatio,grRateKO,grRateWT,hasEffect,delRxns] = singleGeneDeletion(model,'MOMA',DT_model)
# hasEffect_DT=find(hasEffect==1)
# hasEffect_DTgenes=DT_model(hasEffect_DT)
# [grRatio,grRateKO,grRateWT,hasEffect,delRxns,fluxSolution] = singleGeneDeletion(model,'MOMA',hasEffect_DTgenes)
# ```

# %%
model, geneInd2genes, HasEffects_Gene, fluxSolution, fluxSolutionRatios, fluxSolutionDiffs = \
            knock_out_simulation(datadir=configs.datadir,
                                  model_file='Th1_Cell_SpecificModel4manuscript.mat',
                                  inhibitors='Th1_inhibitors_Entrez.txt')
# Out:
# 1133
# 1133
# 247

# %%
inhibitors='Th1_inhibitors_Entrez.txt'
DT_genes = pd.read_csv(os.path.join(configs.datadir,inhibitors), header=None)
DT_genes.rename(columns={0:'Gene ID'},inplace=True)
DT_genes['Gene ID'] = DT_genes['Gene ID'].astype(str)

geneInd2genes = [x.id for x in model.genes]
print(len(geneInd2genes))
geneInd2genes = set(geneInd2genes)
print(len(geneInd2genes))
DT_model = set(DT_genes['Gene ID'].tolist()).intersection(geneInd2genes)
print(len(DT_model))
DT_model = list(DT_model)
# Out:
# 1133
# 1133
# 247

# %%
single_delete = single_gene_deletion(model,DT_model)
single_delete
# Out:
#           growth   status
# ids
# (6898)  1.722327  optimal
# (4353)  1.722327  optimal
# (9194)  1.722327  optimal
# (9123)  1.722327  optimal
# (8435)  1.722327  optimal
# ...          ...      ...
# (107)   1.722327  optimal
# (5832)  1.722327  optimal
# (128)   1.722327  optimal
# (5033)  1.722327  optimal
# (1559)  1.722327  optimal
#
# [247 rows x 2 columns]

# %%
single_delete.loc[abs(abs(single_delete['growth'])-1.722327)>1e-6].sort_index()
# DT_model
# Out:
#                growth   status
# ids
# (6713)   0.000000e+00  optimal
# (7296)   3.333077e-16  optimal
# (7298)   2.673306e-16  optimal
# (3156)  -2.572702e-14  optimal
# (10682) -1.060841e-14  optimal
# (3158)   1.416037e+00  optimal
# (4047)   1.524959e-14  optimal
# (1595)   0.000000e+00  optimal
# (31)     1.644463e-14  optimal
# (2222)  -1.160295e-14  optimal
# (2194)  -7.796084e-15  optimal
# (1723)   0.000000e+00  optimal
# (790)    0.000000e+00  optimal
# (1719)   0.000000e+00  optimal

# %%
single_rxn_delete = single_reaction_deletion(model)

# %%
# single_rxn_delete
# model_opt
fluxSolution
# Out:
#                               513       132      6392      5337      1376  \
# ASNS1                    0.000000  0.000000  0.000000  0.000000  0.000000
# ASPNATm                  0.000000  0.000000  0.000000  0.000000  0.000000
# ASPTA                   -2.003774 -1.044418 -1.044418 -1.044418 -1.044418
# ASPTAm                   0.000000  0.000000  0.000000  0.000000  0.000000
# ACGAMK                   0.001889  0.001889  0.001889  0.001889  0.001889
# ...                           ...       ...       ...       ...       ...
# RE2948C                  0.000000  0.000000  0.000000  0.000000  0.000000
# AIRCr_PRASCS             0.000000  0.000000  0.221713  0.000000  0.000000
# biomass_reaction_Mphage  1.722327  1.722327  1.722327  1.722327  1.722327
# RTOT_3                   0.002362  0.002362  0.002362  0.002362  0.002362
# ARTFR13                  0.002699  0.002699  0.002699  0.002699  0.002699
#
#                              7915      3417      4535  4047      2539  ...  \
# ...

# %%
model_file='Th1_Cell_SpecificModel4manuscript.mat'
model = cobra.io.load_matlab_model(os.path.join(configs.datadir, model_file))

# %%
# model_opt = moma(model).to_frame()
model_opt = model.optimize(objective_sense='maxmize').to_frame()
model_opt
# Out:
#                            fluxes  reduced_costs
# ASNS1                    0.000000  -5.543440e-15
# ASPNATm                  0.000000  -5.697636e-15
# ASPTA                   -1.013774  -1.972152e-31
# ASPTAm                   0.000000   0.000000e+00
# ACGAMK                   0.216395   1.577722e-30
# ...                           ...            ...
# RE2948C                  0.000000  -1.963658e-15
# AIRCr_PRASCS             0.000000   1.405409e-17
# biomass_reaction_Mphage  1.722327  -3.533586e-16
# RTOT_3                   0.270494   0.000000e+00
# ARTFR13                  0.309136   0.000000e+00
#
# [3956 rows x 2 columns]

# %%
model_opt.index.name='rxn'
model_opt.to_csv('WideType_Solution_py.csv')

# %%
model_opt = moma(model).to_frame()
# model_opt = model.optimize(objective_sense='maxmize').to_frame()
model_opt[abs(model_opt) < 1e-8] = 0.0
fluxsolution = pd.DataFrame()
id='100'
model_cp = copy.deepcopy(model)
gene = model_cp.genes.get_by_id(id)
gene.knock_out()
opt_model = moma(model_cp).to_frame()
# opt_model = model_cp.optimize(objective_sense='maxmize').to_frame()
fluxsolution['origin'] = model_opt['fluxes']
fluxsolution[id]=opt_model['fluxes']
# aft_model = moma(model_cp).to_frame()
# fluxsolution['recover'] = aft_model['fluxes']

# %%
# fluxsolution['ratio'] = fluxsolution[id]/fluxsolution['origin']
# fluxsolution['diff'] = fluxsolution[id] - fluxsolution['origin']
# fluxsolution['verify'] = fluxsolution['recover'] - fluxsolution['origin']
temp = (fluxsolution['origin']-fluxsolution['100'])
temp[abs(temp)>1e-6]
# Out:
# r0615         1.057346
# r0617        -1.057346
# DHCR242r      0.132058
# r0783         0.132058
# DHFR         -4.176099
# MTHFD2m      -0.443426
# MTHFDm        0.443426
# r0224         0.925288
# r0226         3.250811
# GLUDxm       -1.396880
# GLUDym        1.396880
# DURAD2       -3.250811
# r0331        -3.250811
# ME1m         -1.410505
# ME2m          1.410505
# FADH2tru      0.132058
# FADtru        0.132058
# Htr          -0.132058
# NADPHtru     -0.132058
# NADPtru      -0.132058
# ASNt4        -0.446995
# GLYSNAT5tc   -2.000000
# HMR_9605      2.000000
# LEUt4         0.446995
# r1549         1.000000
# r1554         1.000000
# r1563        -1.000000
# r1568        -1.000000
# r1647        -0.446995
# r1656         0.446995
# DHFtm         3.250811
# r0921        -3.250811
# r0975        -3.250811
# THFtm        -3.250811
# RE3347C       0.132058
# dtype: float64

# %%
fluxsolution.loc[(~fluxsolution['ratio'].isna()) & ((abs(fluxsolution['origin']) + abs(fluxsolution['diff']))>1e-10)]
# Out:
#                            origin      5244     ratio          diff
# ASPTA                   -1.332995 -4.285686  3.215081 -2.952691e+00
# ACGAMK                   0.068190  0.001889  0.027707 -6.630034e-02
# ACGAMPM                  0.068190  0.001889  0.027707 -6.630034e-02
# UAGDP                    0.068190  0.001889  0.027707 -6.630034e-02
# HMR_4422                 1.000000  1.000000  1.000000 -2.220446e-16
# ...                           ...       ...       ...           ...
# VALTAm                   0.401991  0.000000  0.000000 -4.019910e-01
# AIRCr_PRASCS            -9.652329  0.000000 -0.000000  9.652329e+00
# biomass_reaction_Mphage  1.722327  1.722327  1.000000 -3.996803e-15
# RTOT_3                   0.085237  0.002362  0.027707 -8.287542e-02
# ARTFR13                  0.097414  0.002699  0.027707 -9.471477e-02
#
# [496 rows x 4 columns]

# %%
print(fluxSolutionRatios.shape)
fluxSolutionRatios['100']
# Out:
# (3956, 99)
# ASNS1                           NaN
# ASPNATm                         NaN
# ASPTA                      3.215081
# ASPTAm                          NaN
# ACGAMK                     0.027707
#                              ...
# RE2948C                         NaN
# AIRCr_PRASCS              -0.000000
# biomass_reaction_Mphage    1.000000
# RTOT_3                     0.027707
# ARTFR13                    0.027707
# Name: 100, Length: 3956, dtype: float64

# %%
Gene_Pairs_down = create_gene_pairs(configs.datadir,
                                   model,
                                   geneInd2genes,
                                   fluxSolution, fluxSolutionRatios, fluxSolutionDiffs,
                                   HasEffects_Gene,
                                   RA_Down='RA_DOWN.txt')
# Gene_Pairs_down.to_csv(os.path.join(configs.datadir,'Gene_Pairs_Inhi_Fratio_DOWN.txt'),index=False)
Gene_Pairs_down
# Out:
#      reaction Gene IDs  rxn_fluxRatio  Gene
# 0        DHFR     1719      -0.000000  6898
# 1       r0226     1719       0.000000  6898
# 2       r0224     1719            inf  6898
# 3       GLNt4    81539            inf  6898
# 4       THRt4    81539            inf  6898
# ...       ...      ...            ...   ...
# 3034    RNDR3     6241       0.335463   291
# 3035    r0475     6241            inf   291
# 3036    RNDR4     6241            inf   291
# 3037  MMSAD3m     4329       0.000000   291
# 3038   LCADim     4329       1.238997   291
#
# [3039 rows x 4 columns]

# %%
Gene_Pairs_up = create_gene_pairs(configs.datadir,
                                   model,
                                   geneInd2genes,
                                   fluxSolution, fluxSolutionRatios, fluxSolutionDiffs,
                                   HasEffects_Gene,
                                   RA_Down='RA_UP.txt')
# Gene_Pairs_up.to_csv(os.path.join(configs.datadir,'Gene_Pairs_Inhi_Fratio_UP.txt'),index=False)
Gene_Pairs_up
# Out:
#         reaction Gene IDs  rxn_fluxRatio  Gene
# 0         GLCt1r   144195            inf  6898
# 1           GALU     7360            inf  6898
# 2         GLCt1r     6515            inf  6898
# 3         LSTO1r     6309       1.000000  6898
# 4          KCC2t     9990           -inf  6898
# ..           ...      ...            ...   ...
# 753       GLCt1r     6515            inf   291
# 754       LSTO1r     6309       1.000000   291
# 755        KCC2t     9990           -inf   291
# 756  NADH2_u10mi     4710       0.932955   291
# 757  NADH2_u10mi     4714       0.932955   291
#
# [758 rows x 4 columns]

# %%
print(len(HasEffects_Gene))
print(len(geneInd2genes))
print(Gene_Pairs_up.Gene.unique().size)
print(Gene_Pairs_down.Gene.unique().size)
# Out:
# 118
# 1133
# 118
# 118

# %%
p_model_genes = Gene_Pairs_up.Gene.unique()
d_score = pd.DataFrame([],columns=['score'])
for p_gene in p_model_genes:
    data_p = Gene_Pairs_up.loc[Gene_Pairs_up['Gene']==p_gene].copy()
    # print(data_p)
    total_aff = data_p['Gene IDs'].unique().size
    # print(total_aff)
    n_aff_down=data_p.loc[data_p['rxn_fluxRatio']<-1e-8, 'Gene IDs'].unique().size
    # print(n_aff_down)
    n_aff_up=data_p.loc[data_p['rxn_fluxRatio'] >1e-8, 'Gene IDs'].unique().size
    # print(n_aff_up)
    d_s=((n_aff_down - n_aff_up)/total_aff)
    # print(d_s)
    d_score.at[p_gene,'score'] = d_s

d_score.index.name='Gene'
# d_score.to_csv(os.path.join(configs.datadir,'d_score_UP.csv'))
d_score
# Out:
#           score
# Gene
# 132   -0.111111
# 3099  -0.111111
# 5831  -0.111111
# 4953  -0.111111
# 51727 -0.111111
# ...         ...
# 5321   0.222222
# 3418   0.222222
# 7298   0.222222
# 586    0.222222
# 4535   0.222222
#
# [133 rows x 1 columns]

# %%
d_score_down = score_gene_pairs(Gene_Pairs_down, 'd_score_DOWN.csv')
d_score_up = score_gene_pairs(Gene_Pairs_up, 'd_score_UP.csv')
# print(d_score_down)
d_score_up
# Out:
#           score
# Gene
# 6898  -0.285714
# 5625  -0.285714
# 11254 -0.285714
# 506   -0.285714
# 6515  -0.285714
# ...         ...
# 6392  -0.857143
# 6648  -0.285714
# 2222          0
# 4191  -0.285714
# 291   -0.285714
#
# [110 rows x 1 columns]

# %%
PES = (d_score_up-d_score_down).sort_values(by='score',ascending=False)
PES
# Out:
#          score
# Gene
# 1431 -0.185714
# 2805      -0.3
# 5162 -0.376623
# 506  -0.385714
# 513  -0.385714
# ...        ...
# 7298 -0.842857
# 6392 -0.857143
# 6470 -0.857143
# 3418 -0.857143
# 4967      -0.9
#
# [110 rows x 1 columns]

# %% [markdown]
# create network of genes based on the change
#
# ```m
# gene_mat_out=[];
# for i = 1:length(hasEffect_DTgenes)
#     FR_i=DAG_rxn_fluxRatio(:,i)
#     naN_ind= find(isnan(DAG_rxn_fluxRatio(:,i)))
#     FR_i([naN_ind])=[];
#     Gene_i=combined_output{1}
#     Gene_i([naN_ind])=[];
#     Rind_i=combined_output{2}
#     Rind_i([naN_ind])=[];
#
#     P_gene=repelem(hasEffect_DTgenes(i),length(Gene_i))
#     P_gene=P_gene'
#     pegene_mat=[P_gene Gene_i num2cell(FR_i)]
#     gene_mat_out=[gene_mat_out; pegene_mat]
# end
#
# % Change_file_name here
# T = cell2table(gene_mat_out);
# writetable(T,'Gene_Pairs_Inhi_Fratio_DOWN.txt')
# ```

# %%
temp  =pd.read_csv(os.path.join(configs.rootdir,'code','Gene_Pairs_Inhi_Fratio_UP.txt'))
temp.rename(columns={'gene_mat_out1':'Gene','gene_mat_out2':'Gene IDs','gene_mat_out3':'rxn_fluxRatio'},inplace=True)
temp.Gene = temp.Gene.astype(str)
temp['Gene IDs'] = temp['Gene IDs'].astype(str)

# %%
d_score_temp =score_gene_pairs(temp, 'd_score_temp.csv')
d_score_temp
# Out:
#             score
# Gene
# 100         0.625
# 10135         0.5
# 10682   0.0769231
# 114971      0.625
# 128         0.625
# ...           ...
# 847      0.181818
# 8833        0.625
# 9194        0.625
# 9453      -0.1875
# 952           0.5
#
# [99 rows x 1 columns]

# %%
load_haseffect = set(temp.Gene.tolist())
# load_haseffect
calc_haseffect = set(ld_d_score_Up.index.values)
print(load_haseffect.intersection(calc_haseffect))
print(load_haseffect.intersection(set(DT_model)))
# print(calc_haseffect)
print(calc_haseffect.intersection(set(DT_model)))
# Out:
# {'5162', '515', '513', '790', '2653', '3418', '1719', '5337', '2181', '5471', '26', '5315', '6515', '1595', '2222', '471', '2731', '4535', '18', '5831', '10682', '3156', '3992', '2805', '6648', '6240', '6470', '6526', '3417', '9194', '7298', '587', '5198', '31', '4967', '5832', '50484', '38', '4953', '498', '6713', '506', '3158', '7296', '9453', '84532', '6241', '509', '2194', '6392', '7915', '1723', '128', '4718', '4860', '2618', '51727', '55902', '4047', '2806', '1431', '847', '5625'}
# ...

# %%
df = pd.read_csv(os.path.join(configs.rootdir,'code','bm_d_score_UP.txt'), sep=' ')
bm_d_score_Up = pd.DataFrame(df.x.str.split(' ',1).tolist(), columns = ['Gene','score'])
bm_d_score_Up.set_index('Gene', inplace=True)
bm_d_score_Up.score = bm_d_score_Up.score.astype(float)
df = pd.read_csv(os.path.join(configs.rootdir,'code','bm_d_score_DOWN.txt'), sep=' ')
bm_d_score_Down = pd.DataFrame(df.x.str.split(' ',1).tolist(), columns = ['Gene','score'])
bm_d_score_Down.set_index('Gene', inplace=True)
bm_d_score_Down.score = bm_d_score_Down.score.astype(float)

# %%
d_score_temp.at['100','score']
# Out:
# 0.625

# %%
ld_d_score_Up = pd.read_csv(os.path.join(configs.datadir,'d_score_UP.csv'),index_col='Gene')
ld_d_score_Up.index=ld_d_score_Up.index.values.astype(str)
ld_d_score_Down = pd.read_csv(os.path.join(configs.datadir,'d_score_DOWN.csv'),index_col='Gene')
ld_d_score_Down.index=ld_d_score_Down.index.values.astype(str)

# %%
set1 = set(ld_d_score_Up.index.values).intersection(set(bm_d_score_Up.index.values))
print(len(set1))
test_compare = pd.DataFrame()
test_compare['UP'] = (ld_d_score_Up - bm_d_score_Up)['score']
test_compare['DOWN'] = (-ld_d_score_Down - bm_d_score_Down)['score']
test_compare['PES'] = test_compare['UP'] + test_compare['DOWN']
test_compare.describe()
# Out:
# 99
#               UP       DOWN        PES
# count  99.000000  99.000000  99.000000
# mean   -0.309584  -0.079309  -0.388893
# std     0.313712   0.382096   0.271441
# min    -1.000000  -1.075000  -1.033333
# 25%    -0.500000  -0.215074  -0.490152
# 50%    -0.375000  -0.005682  -0.322222
# 75%    -0.071429   0.172727  -0.236179
# max     0.330357   0.354545   0.131746

# %%
show_d_score_rank(ld_d_score_Up, ld_d_score_Down)
# Out:
#            score
# count  99.000000
# mean    0.044169
# std     0.214682
# min    -0.600000
# 25%    -0.050000
# 50%     0.033333
# 75%     0.200000
# max     0.500000
#          score
# 1806  0.500000
# 26    0.400000
# 5832  0.400000
# 38    0.400000
# 4953  0.400000
# ...        ...
# 5625 -0.366667
# 5471 -0.400000
# 6240 -0.566667
# 6241 -0.566667
# 2805 -0.600000
#
# [99 rows x 1 columns]

# %%
def show_d_score_rank(d_score_up_bench, d_score_down_bench):
    d_score_rank = (d_score_up_bench - d_score_down_bench)
    d_score_rank.score = d_score_rank.score.astype(float)
    d_score_rank.index=d_score_rank.index.values.astype(str)
    d_score_rank = d_score_rank.sort_values(by='score',ascending=False)
    print(d_score_rank.describe())
    return d_score_rank

# %%
show_d_score_rank(d_score_up_bench, d_score_down_bench)
# Out:
#            score
# count  99.000000
# mean    0.209513
# std     0.175370
# min    -0.250000
# 25%     0.100000
# 50%     0.225000
# 75%     0.308622
# max     0.636364
#          score
# 4907  0.636364
# 498   0.545455
# 506   0.545455
# 509   0.545455
# 513   0.545455
# ...        ...
# 1312 -0.066667
# 3704 -0.068182
# 790  -0.078947
# 4953 -0.233333
# 47   -0.250000
#
# [99 rows x 1 columns]

# %%
show_d_score_rank(d_score_up, d_score_down)
# Out:
#            score
# count  99.000000
# mean    0.044169
# std     0.214682
# min    -0.600000
# 25%    -0.050000
# 50%     0.033333
# 75%     0.200000
# max     0.500000
#          score
# 1806  0.500000
# 26    0.400000
# 5832  0.400000
# 38    0.400000
# 4953  0.400000
# ...        ...
# 5625 -0.366667
# 5471 -0.400000
# 6240 -0.566667
# 6241 -0.566667
# 2805 -0.600000
#
# [99 rows x 1 columns]

# %%
def load_Inhi_Fratio(filepath):
    temp2  =pd.read_csv(filepath)
    temp2.rename(columns={'gene_mat_out1':'Gene','gene_mat_out2':'Gene IDs','gene_mat_out3':'rxn_fluxRatio'},inplace=True)
    temp2.Gene = temp2.Gene.astype(str)
    temp2['Gene IDs'] = temp2['Gene IDs'].astype(str)
    return temp2

# %%
def score_gene_pairs(Gene_Pairs, filename):
    p_model_genes = Gene_Pairs.Gene.unique()
    d_score = pd.DataFrame([], columns=['score'])
    for p_gene in p_model_genes:
        data_p = Gene_Pairs.loc[Gene_Pairs['Gene'] == p_gene].copy()
        # print(data_p)
        total_aff = data_p['Gene IDs'].unique().size
        # print(total_aff)
        n_aff_down = data_p.loc[data_p['rxn_fluxRatio'] < 0.99, 'Gene IDs'].unique().size
        # print(n_aff_down)
        n_aff_up = data_p.loc[data_p['rxn_fluxRatio'] > 1.0, 'Gene IDs'].unique().size
        # print(n_aff_up)
        d_s = ((n_aff_down - n_aff_up) / total_aff)
        # print(d_s)
        d_score.at[p_gene, 'score'] = d_s

    d_score.index.name = 'Gene'
    d_score.to_csv(os.path.join(configs.datadir, filename))
    return d_score

# %%
set1 = set(temp2.Gene.tolist()).intersection(set(DT_model))
set2 = set(temp2.Gene.tolist()).intersection(set(temp.Gene.tolist()))
print(len(set1))
print(set1)
print(len(set2))
print(set2)
# Out:
# 110
# {'36', '5162', '2653', '5337', '5315', '6541', '29920', '59272', '18', '1056', '5831', '5313', '6240', '6526', '3417', '23539', '5832', '1503', '38', '2182', '4860', '51727', '763', '55902', '4047', '1431', '27165', '5321', '6566', '2752', '5160', '3418', '1719', '26', '51557', '6514', '79751', '1595', '6513', '471', '291', '4535', '9123', '10682', '4191', '2180', '84889', '6542', '4967', '498', '9453', '509', '6392', '7915', '2194', '125', '128', '4718', '217', '513', '790', '10449', '2181', '5471', '6515', '83733', '2222', '11254', '2744', '3099', '3156', '6319', '6648', '6470', '9194', '31', '7296', '84532', '6241', '8854', '2618', '2747', '32', '6898', '10327', '11238', '847', '515', '115584', '6517', '2731', '2645', '3992', '2805', '7298', '587', '5198', '50484', '4953', '6524', '6713', '506', '3158', '2746', '1723', '126', '231', '4522', '2806', '5625'}
# 63
# ...

# %%
Gene_Pairs_Up_bench = load_Inhi_Fratio(os.path.join(configs.rootdir,'code','Gene_Pairs_Inhi_Fratio_UP.txt'))
Gene_Pairs_Down_bench = load_Inhi_Fratio(os.path.join(configs.rootdir,'code','Gene_Pairs_Inhi_Fratio_DOWN.txt'))
d_score_up_bench = score_gene_pairs(Gene_Pairs_Up_bench, 'd_score_up_bench.csv')
d_score_down_bench = score_gene_pairs(Gene_Pairs_Down_bench, 'd_score_down_bench.csv')

# %%
Gene_Pairs_Up = load_Inhi_Fratio(os.path.join(configs.rootdir,'data','Gene_Pairs_Inhi_Fratio_UP.txt'))
Gene_Pairs_Down = load_Inhi_Fratio(os.path.join(configs.rootdir,'data','Gene_Pairs_Inhi_Fratio_DOWN.txt'))
d_score_up = score_gene_pairs(Gene_Pairs_Up, 'd_score_up_test.csv')
d_score_down = score_gene_pairs(Gene_Pairs_Down, 'd_score_down_test.csv')

# %%
print((d_score_up - d_score_down).sort_values(by='score',ascending=False).describe())
(d_score_up - d_score_down).sort_values(by='score',ascending=False)
# Out:
#         score
# count    99.0
# unique   24.0
# top       0.2
# freq     19.0
#          score
# Gene
# 1806       0.5
# 26         0.4
# 5832       0.4
# 38         0.4
# 4953       0.4
# ...        ...
# 5625 -0.366667
# 5471      -0.4
# 6240 -0.566667
# 6241 -0.566667
# 2805      -0.6
#
# [99 rows x 1 columns]

# %%
Gene_Pairs_Up_bench
# Out:
#      Gene Gene IDs  rxn_fluxRatio
# 0     100     6309       1.000000
# 1     100     7360       1.000000
# 2     100    56261       1.000000
# 3     100     5286           -inf
# 4     100     9583       0.647708
# ...   ...      ...            ...
# 1100  952     4714       1.000000
# 1101  952     6515       1.000000
# 1102  952   144195       1.000000
# 1103  952     9990       1.000000
# 1104  952     9990       1.000000
#
# [1105 rows x 3 columns]

# %%
Gene_Pairs_Up.sort_values(by='Gene')
# Out:
#         reaction Gene IDs  rxn_fluxRatio Gene
# 222  NADH2_u10mi     4710            1.0  100
# 223       LSTO1r     6309            1.0  100
# 224       GLCt1r     6515            1.0  100
# 225         GALU     7360            1.0  100
# 226  NADH2_u10mi     4714            1.0  100
# ..           ...      ...            ...  ...
# 238  NADH2_u10mi     4714            1.0  952
# 234  NADH2_u10mi     4710            1.0  952
# 235       LSTO1r     6309            1.0  952
# 236       GLCt1r     6515            1.0  952
# 237         GALU     7360            1.0  952
#
# [594 rows x 4 columns]

# %%
d_score_up_bench - ld_d_score_Up
# Out:
#            score
# 100     0.166667
# 10135  -0.166667
# 10682  -1.187500
# 114971  0.166667
# 128    -0.333333
# ...          ...
# 847    -0.055556
# 8833   -0.400000
# 9194   -0.033333
# 9453   -0.250000
# 952    -0.133333
#
# [99 rows x 1 columns]

# %%
means = np.random.random([4,8])
variance = np.random.random([4,8])
